# %%
import sys
import gym
import torch
import pylab
import random
import numpy as np
from collections import deque
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import transforms
from prioritized_memory import Memory

# %%
seed = 161
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

# %%
EPISODES = 500

# %%
# approximate Q function using Neural Network
# state is input and Q Value of each action is output of network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_size, 24),
            nn.ReLU(),
            nn.Linear(24, 24),
            nn.ReLU(),
            nn.Linear(24, action_size)
        )

    def forward(self, x):
        return self.fc(x)

# %%
# DQN Agent for the Cartpole
# it uses Neural Network to approximate q function
# and prioritized experience replay memory & target q network
class DQNAgent():
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False

        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # These are hyper parameters for the DQN
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.memory_size = 20000
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.explore_step = 5000
        self.epsilon_decay = (self.epsilon - self.epsilon_min) / self.explore_step
        self.batch_size = 64
        self.train_start = 1000

        # create prioritized replay memory using SumTree
        self.memory = Memory(self.memory_size)

        # create main model and target model
        self.model = DQN(state_size, action_size)
        self.model.apply(self.weights_init)
        self.target_model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(),
                                    lr=self.learning_rate)

        # initialize target model
        self.update_target_model()

        if self.load_model:
            self.model = torch.load('save_model/cartpole_dqn')

    # weight xavier initialize
    def weights_init(self, m):
        classname = m.__class__.__name__
        if classname.find('Linear') != -1:
            torch.nn.init.xavier_uniform(m.weight)

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    # get action from model using epsilon-greedy policy
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            state = torch.from_numpy(state)
            state = Variable(state).float().cpu()
            q_value = self.model(state)
            _, action = torch.max(q_value, 1)
            return int(action)

    # save sample (error,<s,a,r,s'>) to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        target = self.model(Variable(torch.FloatTensor(state))).data
        old_val = target[0][action]
        target_val = self.target_model(Variable(torch.FloatTensor(next_state))).data
        if done:
            target[0][action] = reward
        else:
            target[0][action] = reward + self.discount_factor * torch.max(target_val)

        error = abs(old_val - target[0][action])

        self.memory.add(error, (state, action, reward, next_state, done))

    # pick samples from prioritized replay memory (with batch_size)
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay

        mini_batch, idxs, is_weights = self.memory.sample(self.batch_size)
        mini_batch = np.array(mini_batch).transpose()

        states = np.vstack(mini_batch[0])
        actions = list(mini_batch[1])
        rewards = list(mini_batch[2])
        next_states = np.vstack(mini_batch[3])
        dones = mini_batch[4]

        # bool to binary
        dones = dones.astype(int)

        # Q function of current state
        states = torch.Tensor(states)
        states = Variable(states).float()
        pred = self.model(states)

        # one-hot encoding
        a = torch.LongTensor(actions).view(-1, 1)

        one_hot_action = torch.FloatTensor(self.batch_size, self.action_size).zero_()
        one_hot_action.scatter_(1, a, 1)

        pred = torch.sum(pred.mul(Variable(one_hot_action)), dim=1)

        # Q function of next state
        next_states = torch.Tensor(next_states)
        next_states = Variable(next_states).float()
        next_pred = self.target_model(next_states).data

        rewards = torch.FloatTensor(rewards)
        dones = torch.FloatTensor(dones)

        # Q Learning: get maximum Q value at s' from target model
        target = rewards + (1 - dones) * self.discount_factor * next_pred.max(1)[0]
        target = Variable(target)

        errors = torch.abs(pred - target).data.numpy()

        # update priority
        for i in range(self.batch_size):
            idx = idxs[i]
            self.memory.update(idx, errors[i])

        self.optimizer.zero_grad()

        # MSE Loss function
        loss = F.mse_loss(pred, target)
        loss.backward()

        # and train
        self.optimizer.step()

# %%
# In case of CartPole-v1, maximum length of episode is 500
env = gym.make('CartPole-v0')
env.seed(seed)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
model = DQN(state_size, action_size)

agent = DQNAgent(state_size, action_size)
scores, episodes = [], []

for e in range(EPISODES):
    done = False
    score = 0

    state = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        if agent.render:
            env.render()

        # get action for the current state and go one step in environment
        action = agent.get_action(state)

        next_state, reward, done, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        # if an action make the episode end, then gives penalty of -100
        reward = reward if not done or score == 199 else -1

        # save the sample <s, a, r, s'> to the replay memory
        agent.append_sample(state, action, reward, next_state, done)
        # every time step do the training
        if agent.memory.tree.n_entries >= agent.train_start:
            agent.train_model()

        score += reward
        state = next_state

        if done:
            # every episode update the target model to be same with model
            TARGET_REPLACE_ITER = 100
            if(e%TARGET_REPLACE_ITER == 0):
                agent.update_target_model()

            # every episode, plot the play time
#             score = score if score == 500 else score + 10
            scores.append(score)
            episodes.append(e)
#             pylab.plot(episodes, scores, 'b')
#             pylab.savefig("./save_graph/cartpole_dqn.png")
#             print("episode:", e, "  score:", score, "  memory length:", agent.memory.tree.n_entries, "  epsilon:", agent.epsilon)
            print("EPISODE#{:4d} | SCORE: {:6d} | MEMORY_LENGTH: {:10d} | EPSILON: {:6.3f}".format(int(e), int(score), int(agent.memory.tree.n_entries), agent.epsilon))

            # if the mean of scores of last 10 episode is bigger than 490
            # stop training
#             if np.mean(scores[-min(10, len(scores)):]) > 490:
#                 torch.save(agent.model, "./save_model/cartpole_dqn")
#                 sys.exit()
#                 break

pylab.plot(episodes, scores, 'b')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# EPISODE#   0 | SCORE:     14 | MEMORY_LENGTH:         16 | EPSILON:  1.000
# EPISODE#   1 | SCORE:     10 | MEMORY_LENGTH:         28 | EPSILON:  1.000
# EPISODE#   2 | SCORE:     32 | MEMORY_LENGTH:         62 | EPSILON:  1.000
# EPISODE#   3 | SCORE:     34 | MEMORY_LENGTH:         98 | EPSILON:  1.000
# EPISODE#   4 | SCORE:     41 | MEMORY_LENGTH:        141 | EPSILON:  1.000
# EPISODE#   5 | SCORE:     21 | MEMORY_LENGTH:        164 | EPSILON:  1.000
# EPISODE#   6 | SCORE:     29 | MEMORY_LENGTH:        195 | EPSILON:  1.000
# EPISODE#   7 | SCORE:     44 | MEMORY_LENGTH:        241 | EPSILON:  1.000
# EPISODE#   8 | SCORE:     12 | MEMORY_LENGTH:        255 | EPSILON:  1.000
# EPISODE#   9 | SCORE:     31 | MEMORY_LENGTH:        288 | EPSILON:  1.000
# EPISODE#  10 | SCORE:     20 | MEMORY_LENGTH:        310 | EPSILON:  1.000
# EPISODE#  11 | SCORE:     24 | MEMORY_LENGTH:        336 | EPSILON:  1.000
# EPISODE#  12 | SCORE:     91 | MEMORY_LENGTH:        429 | EPSILON:  1.000
# EPISODE#  13 | SCORE:     21 | MEMORY_LENGTH:        452 | EPSILON:  1.000
# EPISODE#  14 | SCORE:     24 | MEMORY_LENGTH:        478 | EPSILON:  1.000
# EPISODE#  15 | SCORE:     11 | MEMORY_LENGTH:        491 | EPSILON:  1.000
# EPISODE#  16 | SCORE:     31 | MEMORY_LENGTH:        524 | EPSILON:  1.000
# EPISODE#  17 | SCORE:     19 | MEMORY_LENGTH:        545 | EPSILON:  1.000
# EPISODE#  18 | SCORE:     50 | MEMORY_LENGTH:        597 | EPSILON:  1.000
# EPISODE#  19 | SCORE:     11 | MEMORY_LENGTH:        610 | EPSILON:  1.000
# EPISODE#  20 | SCORE:     11 | MEMORY_LENGTH:        623 | EPSILON:  1.000
# EPISODE#  21 | SCORE:     12 | MEMORY_LENGTH:        637 | EPSILON:  1.000
# EPISODE#  22 | SCORE:     27 | MEMORY_LENGTH:        666 | EPSILON:  1.000
# EPISODE#  23 | SCORE:      7 | MEMORY_LENGTH:        675 | EPSILON:  1.000
# EPISODE#  24 | SCORE:     35 | MEMORY_LENGTH:        712 | EPSILON:  1.000
# EPISODE#  25 | SCORE:     19 | MEMORY_LENGTH:        733 | EPSILON:  1.000
# EPISODE#  26 | SCORE:     20 | MEMORY_LENGTH:        755 | EPSILON:  1.000
# EPISODE#  27 | SCORE:     27 | MEMORY_LENGTH:        784 | EPSILON:  1.000
# EPISODE#  28 | SCORE:     21 | MEMORY_LENGTH:        807 | EPSILON:  1.000
# EPISODE#  29 | SCORE:      9 | MEMORY_LENGTH:        818 | EPSILON:  1.000
# EPISODE#  30 | SCORE:     14 | MEMORY_LENGTH:        834 | EPSILON:  1.000
# EPISODE#  31 | SCORE:     32 | MEMORY_LENGTH:        868 | EPSILON:  1.000
# EPISODE#  32 | SCORE:     18 | MEMORY_LENGTH:        888 | EPSILON:  1.000
# EPISODE#  33 | SCORE:     13 | MEMORY_LENGTH:        903 | EPSILON:  1.000
# EPISODE#  34 | SCORE:     15 | MEMORY_LENGTH:        920 | EPSILON:  1.000
# EPISODE#  35 | SCORE:     29 | MEMORY_LENGTH:        951 | EPSILON:  1.000
# EPISODE#  36 | SCORE:     11 | MEMORY_LENGTH:        964 | EPSILON:  1.000
# EPISODE#  37 | SCORE:     13 | MEMORY_LENGTH:        979 | EPSILON:  1.000
# EPISODE#  38 | SCORE:     10 | MEMORY_LENGTH:        991 | EPSILON:  1.000
# EPISODE#  39 | SCORE:     44 | MEMORY_LENGTH:       1037 | EPSILON:  0.992
# EPISODE#  40 | SCORE:      9 | MEMORY_LENGTH:       1048 | EPSILON:  0.990
# EPISODE#  41 | SCORE:     13 | MEMORY_LENGTH:       1063 | EPSILON:  0.987
# EPISODE#  42 | SCORE:     17 | MEMORY_LENGTH:       1082 | EPSILON:  0.984
# EPISODE#  43 | SCORE:     35 | MEMORY_LENGTH:       1119 | EPSILON:  0.976
# EPISODE#  44 | SCORE:     24 | MEMORY_LENGTH:       1145 | EPSILON:  0.971
# EPISODE#  45 | SCORE:      8 | MEMORY_LENGTH:       1155 | EPSILON:  0.969
# EPISODE#  46 | SCORE:     15 | MEMORY_LENGTH:       1172 | EPSILON:  0.966
# EPISODE#  47 | SCORE:     12 | MEMORY_LENGTH:       1186 | EPSILON:  0.963
# EPISODE#  48 | SCORE:     14 | MEMORY_LENGTH:       1202 | EPSILON:  0.960
# EPISODE#  49 | SCORE:     14 | MEMORY_LENGTH:       1218 | EPSILON:  0.957
# EPISODE#  50 | SCORE:     17 | MEMORY_LENGTH:       1237 | EPSILON:  0.953
# EPISODE#  51 | SCORE:     13 | MEMORY_LENGTH:       1252 | EPSILON:  0.950
# EPISODE#  52 | SCORE:     11 | MEMORY_LENGTH:       1265 | EPSILON:  0.947
# EPISODE#  53 | SCORE:     43 | MEMORY_LENGTH:       1310 | EPSILON:  0.938
# EPISODE#  54 | SCORE:      9 | MEMORY_LENGTH:       1321 | EPSILON:  0.936
# EPISODE#  55 | SCORE:     17 | MEMORY_LENGTH:       1340 | EPSILON:  0.932
# EPISODE#  56 | SCORE:     14 | MEMORY_LENGTH:       1356 | EPSILON:  0.929
# EPISODE#  57 | SCORE:     21 | MEMORY_LENGTH:       1379 | EPSILON:  0.925
# EPISODE#  58 | SCORE:     29 | MEMORY_LENGTH:       1410 | EPSILON:  0.919
# EPISODE#  59 | SCORE:     12 | MEMORY_LENGTH:       1424 | EPSILON:  0.916
# EPISODE#  60 | SCORE:     17 | MEMORY_LENGTH:       1443 | EPSILON:  0.912
# EPISODE#  61 | SCORE:     23 | MEMORY_LENGTH:       1468 | EPSILON:  0.907
# EPISODE#  62 | SCORE:      8 | MEMORY_LENGTH:       1478 | EPSILON:  0.905
# EPISODE#  63 | SCORE:     20 | MEMORY_LENGTH:       1500 | EPSILON:  0.901
# EPISODE#  64 | SCORE:     22 | MEMORY_LENGTH:       1524 | EPSILON:  0.896
# EPISODE#  65 | SCORE:     16 | MEMORY_LENGTH:       1542 | EPSILON:  0.892
# EPISODE#  66 | SCORE:     35 | MEMORY_LENGTH:       1579 | EPSILON:  0.885
# EPISODE#  67 | SCORE:     37 | MEMORY_LENGTH:       1618 | EPSILON:  0.877
# EPISODE#  68 | SCORE:      9 | MEMORY_LENGTH:       1629 | EPSILON:  0.875
# EPISODE#  69 | SCORE:     11 | MEMORY_LENGTH:       1642 | EPSILON:  0.873
# EPISODE#  70 | SCORE:      9 | MEMORY_LENGTH:       1653 | EPSILON:  0.871
# EPISODE#  71 | SCORE:      9 | MEMORY_LENGTH:       1664 | EPSILON:  0.868
# EPISODE#  72 | SCORE:     21 | MEMORY_LENGTH:       1687 | EPSILON:  0.864
# EPISODE#  73 | SCORE:     38 | MEMORY_LENGTH:       1727 | EPSILON:  0.856
# EPISODE#  74 | SCORE:     15 | MEMORY_LENGTH:       1744 | EPSILON:  0.852
# EPISODE#  75 | SCORE:     26 | MEMORY_LENGTH:       1772 | EPSILON:  0.847
# EPISODE#  76 | SCORE:     30 | MEMORY_LENGTH:       1804 | EPSILON:  0.841
# EPISODE#  77 | SCORE:     11 | MEMORY_LENGTH:       1817 | EPSILON:  0.838
# EPISODE#  78 | SCORE:     35 | MEMORY_LENGTH:       1854 | EPSILON:  0.831
# EPISODE#  79 | SCORE:     26 | MEMORY_LENGTH:       1882 | EPSILON:  0.825
# EPISODE#  80 | SCORE:     20 | MEMORY_LENGTH:       1904 | EPSILON:  0.821
# EPISODE#  81 | SCORE:     22 | MEMORY_LENGTH:       1928 | EPSILON:  0.816
# EPISODE#  82 | SCORE:     10 | MEMORY_LENGTH:       1940 | EPSILON:  0.814
# EPISODE#  83 | SCORE:     20 | MEMORY_LENGTH:       1962 | EPSILON:  0.809
# EPISODE#  84 | SCORE:     12 | MEMORY_LENGTH:       1976 | EPSILON:  0.807
# EPISODE#  85 | SCORE:     54 | MEMORY_LENGTH:       2032 | EPSILON:  0.795
# EPISODE#  86 | SCORE:     43 | MEMORY_LENGTH:       2077 | EPSILON:  0.787
# EPISODE#  87 | SCORE:      9 | MEMORY_LENGTH:       2088 | EPSILON:  0.784
# EPISODE#  88 | SCORE:     27 | MEMORY_LENGTH:       2117 | EPSILON:  0.779
# EPISODE#  89 | SCORE:     34 | MEMORY_LENGTH:       2153 | EPSILON:  0.772
# EPISODE#  90 | SCORE:     12 | MEMORY_LENGTH:       2167 | EPSILON:  0.769
# EPISODE#  91 | SCORE:     27 | MEMORY_LENGTH:       2196 | EPSILON:  0.763
# EPISODE#  92 | SCORE:     23 | MEMORY_LENGTH:       2221 | EPSILON:  0.758
# EPISODE#  93 | SCORE:     15 | MEMORY_LENGTH:       2238 | EPSILON:  0.755
# EPISODE#  94 | SCORE:     21 | MEMORY_LENGTH:       2261 | EPSILON:  0.750
# EPISODE#  95 | SCORE:      8 | MEMORY_LENGTH:       2271 | EPSILON:  0.748
# EPISODE#  96 | SCORE:     13 | MEMORY_LENGTH:       2286 | EPSILON:  0.745
# EPISODE#  97 | SCORE:     16 | MEMORY_LENGTH:       2304 | EPSILON:  0.742
# EPISODE#  98 | SCORE:     16 | MEMORY_LENGTH:       2322 | EPSILON:  0.738
# EPISODE#  99 | SCORE:     33 | MEMORY_LENGTH:       2357 | EPSILON:  0.731
# EPISODE# 100 | SCORE:     10 | MEMORY_LENGTH:       2369 | EPSILON:  0.729
# EPISODE# 101 | SCORE:     11 | MEMORY_LENGTH:       2382 | EPSILON:  0.726
# EPISODE# 102 | SCORE:     16 | MEMORY_LENGTH:       2400 | EPSILON:  0.723
# EPISODE# 103 | SCORE:      8 | MEMORY_LENGTH:       2410 | EPSILON:  0.721
# EPISODE# 104 | SCORE:     10 | MEMORY_LENGTH:       2422 | EPSILON:  0.718
# EPISODE# 105 | SCORE:     26 | MEMORY_LENGTH:       2450 | EPSILON:  0.713
# EPISODE# 106 | SCORE:     18 | MEMORY_LENGTH:       2470 | EPSILON:  0.709
# EPISODE# 107 | SCORE:      8 | MEMORY_LENGTH:       2480 | EPSILON:  0.707
# EPISODE# 108 | SCORE:      9 | MEMORY_LENGTH:       2491 | EPSILON:  0.705
# EPISODE# 109 | SCORE:     12 | MEMORY_LENGTH:       2505 | EPSILON:  0.702
# EPISODE# 110 | SCORE:     14 | MEMORY_LENGTH:       2521 | EPSILON:  0.699
# EPISODE# 111 | SCORE:     13 | MEMORY_LENGTH:       2536 | EPSILON:  0.696
# EPISODE# 112 | SCORE:     12 | MEMORY_LENGTH:       2550 | EPSILON:  0.693
# EPISODE# 113 | SCORE:     42 | MEMORY_LENGTH:       2594 | EPSILON:  0.684
# EPISODE# 114 | SCORE:     14 | MEMORY_LENGTH:       2610 | EPSILON:  0.681
# EPISODE# 115 | SCORE:     32 | MEMORY_LENGTH:       2644 | EPSILON:  0.674
# EPISODE# 116 | SCORE:     36 | MEMORY_LENGTH:       2682 | EPSILON:  0.667
# EPISODE# 117 | SCORE:     14 | MEMORY_LENGTH:       2698 | EPSILON:  0.664
# EPISODE# 118 | SCORE:     57 | MEMORY_LENGTH:       2757 | EPSILON:  0.652
# EPISODE# 119 | SCORE:     41 | MEMORY_LENGTH:       2800 | EPSILON:  0.643
# EPISODE# 120 | SCORE:     14 | MEMORY_LENGTH:       2816 | EPSILON:  0.640
# EPISODE# 121 | SCORE:     23 | MEMORY_LENGTH:       2841 | EPSILON:  0.635
# EPISODE# 122 | SCORE:      9 | MEMORY_LENGTH:       2852 | EPSILON:  0.633
# EPISODE# 123 | SCORE:     11 | MEMORY_LENGTH:       2865 | EPSILON:  0.631
# EPISODE# 124 | SCORE:     11 | MEMORY_LENGTH:       2878 | EPSILON:  0.628
# EPISODE# 125 | SCORE:     14 | MEMORY_LENGTH:       2894 | EPSILON:  0.625
# EPISODE# 126 | SCORE:     10 | MEMORY_LENGTH:       2906 | EPSILON:  0.622
# EPISODE# 127 | SCORE:     18 | MEMORY_LENGTH:       2926 | EPSILON:  0.618
# EPISODE# 128 | SCORE:     11 | MEMORY_LENGTH:       2939 | EPSILON:  0.616
# EPISODE# 129 | SCORE:     13 | MEMORY_LENGTH:       2954 | EPSILON:  0.613
# EPISODE# 130 | SCORE:     18 | MEMORY_LENGTH:       2974 | EPSILON:  0.609
# EPISODE# 131 | SCORE:     10 | MEMORY_LENGTH:       2986 | EPSILON:  0.607
# EPISODE# 132 | SCORE:     11 | MEMORY_LENGTH:       2999 | EPSILON:  0.604
# EPISODE# 133 | SCORE:     10 | MEMORY_LENGTH:       3011 | EPSILON:  0.602
# EPISODE# 134 | SCORE:     20 | MEMORY_LENGTH:       3033 | EPSILON:  0.597
# EPISODE# 135 | SCORE:     17 | MEMORY_LENGTH:       3052 | EPSILON:  0.594
# EPISODE# 136 | SCORE:     41 | MEMORY_LENGTH:       3095 | EPSILON:  0.585
# EPISODE# 137 | SCORE:     16 | MEMORY_LENGTH:       3113 | EPSILON:  0.581
# EPISODE# 138 | SCORE:     14 | MEMORY_LENGTH:       3129 | EPSILON:  0.578
# EPISODE# 139 | SCORE:     10 | MEMORY_LENGTH:       3141 | EPSILON:  0.576
# EPISODE# 140 | SCORE:      8 | MEMORY_LENGTH:       3151 | EPSILON:  0.574
# EPISODE# 141 | SCORE:     12 | MEMORY_LENGTH:       3165 | EPSILON:  0.571
# EPISODE# 142 | SCORE:     46 | MEMORY_LENGTH:       3213 | EPSILON:  0.562
# EPISODE# 143 | SCORE:      8 | MEMORY_LENGTH:       3223 | EPSILON:  0.560
# EPISODE# 144 | SCORE:     59 | MEMORY_LENGTH:       3284 | EPSILON:  0.548
# EPISODE# 145 | SCORE:      7 | MEMORY_LENGTH:       3293 | EPSILON:  0.546
# EPISODE# 146 | SCORE:     17 | MEMORY_LENGTH:       3312 | EPSILON:  0.542
# EPISODE# 147 | SCORE:      9 | MEMORY_LENGTH:       3323 | EPSILON:  0.540
# EPISODE# 148 | SCORE:     26 | MEMORY_LENGTH:       3351 | EPSILON:  0.534
# EPISODE# 149 | SCORE:     13 | MEMORY_LENGTH:       3366 | EPSILON:  0.531
# EPISODE# 150 | SCORE:     12 | MEMORY_LENGTH:       3380 | EPSILON:  0.529
# EPISODE# 151 | SCORE:     26 | MEMORY_LENGTH:       3408 | EPSILON:  0.523
# EPISODE# 152 | SCORE:     38 | MEMORY_LENGTH:       3448 | EPSILON:  0.515
# EPISODE# 153 | SCORE:     10 | MEMORY_LENGTH:       3460 | EPSILON:  0.513
# EPISODE# 154 | SCORE:     13 | MEMORY_LENGTH:       3475 | EPSILON:  0.510
# EPISODE# 155 | SCORE:     20 | MEMORY_LENGTH:       3497 | EPSILON:  0.505
# EPISODE# 156 | SCORE:     12 | MEMORY_LENGTH:       3511 | EPSILON:  0.503
# EPISODE# 157 | SCORE:     17 | MEMORY_LENGTH:       3530 | EPSILON:  0.499
# EPISODE# 158 | SCORE:     16 | MEMORY_LENGTH:       3548 | EPSILON:  0.495
# EPISODE# 159 | SCORE:     21 | MEMORY_LENGTH:       3571 | EPSILON:  0.491
# EPISODE# 160 | SCORE:     30 | MEMORY_LENGTH:       3603 | EPSILON:  0.484
# EPISODE# 161 | SCORE:      9 | MEMORY_LENGTH:       3614 | EPSILON:  0.482
# EPISODE# 162 | SCORE:      8 | MEMORY_LENGTH:       3624 | EPSILON:  0.480
# EPISODE# 163 | SCORE:     31 | MEMORY_LENGTH:       3657 | EPSILON:  0.474
# EPISODE# 164 | SCORE:     10 | MEMORY_LENGTH:       3669 | EPSILON:  0.471
# EPISODE# 165 | SCORE:     18 | MEMORY_LENGTH:       3689 | EPSILON:  0.467
# EPISODE# 166 | SCORE:     10 | MEMORY_LENGTH:       3701 | EPSILON:  0.465
# EPISODE# 167 | SCORE:     13 | MEMORY_LENGTH:       3716 | EPSILON:  0.462
# EPISODE# 168 | SCORE:      8 | MEMORY_LENGTH:       3726 | EPSILON:  0.460
# EPISODE# 169 | SCORE:     10 | MEMORY_LENGTH:       3738 | EPSILON:  0.458
# EPISODE# 170 | SCORE:     10 | MEMORY_LENGTH:       3750 | EPSILON:  0.455
# EPISODE# 171 | SCORE:      7 | MEMORY_LENGTH:       3759 | EPSILON:  0.454
# EPISODE# 172 | SCORE:     10 | MEMORY_LENGTH:       3771 | EPSILON:  0.451
# EPISODE# 173 | SCORE:     17 | MEMORY_LENGTH:       3790 | EPSILON:  0.447
# EPISODE# 174 | SCORE:     13 | MEMORY_LENGTH:       3805 | EPSILON:  0.444
# EPISODE# 175 | SCORE:      9 | MEMORY_LENGTH:       3816 | EPSILON:  0.442
# EPISODE# 176 | SCORE:     16 | MEMORY_LENGTH:       3834 | EPSILON:  0.439
# EPISODE# 177 | SCORE:     32 | MEMORY_LENGTH:       3868 | EPSILON:  0.432
# EPISODE# 178 | SCORE:     13 | MEMORY_LENGTH:       3883 | EPSILON:  0.429
# EPISODE# 179 | SCORE:     11 | MEMORY_LENGTH:       3896 | EPSILON:  0.426
# EPISODE# 180 | SCORE:      8 | MEMORY_LENGTH:       3906 | EPSILON:  0.424
# EPISODE# 181 | SCORE:     10 | MEMORY_LENGTH:       3918 | EPSILON:  0.422
# EPISODE# 182 | SCORE:     12 | MEMORY_LENGTH:       3932 | EPSILON:  0.419
# EPISODE# 183 | SCORE:      9 | MEMORY_LENGTH:       3943 | EPSILON:  0.417
# EPISODE# 184 | SCORE:     13 | MEMORY_LENGTH:       3958 | EPSILON:  0.414
# EPISODE# 185 | SCORE:      8 | MEMORY_LENGTH:       3968 | EPSILON:  0.412
# EPISODE# 186 | SCORE:     35 | MEMORY_LENGTH:       4005 | EPSILON:  0.405
# EPISODE# 187 | SCORE:     15 | MEMORY_LENGTH:       4022 | EPSILON:  0.401
# EPISODE# 188 | SCORE:     19 | MEMORY_LENGTH:       4043 | EPSILON:  0.397
# EPISODE# 189 | SCORE:     10 | MEMORY_LENGTH:       4055 | EPSILON:  0.395
# EPISODE# 190 | SCORE:      9 | MEMORY_LENGTH:       4066 | EPSILON:  0.393
# EPISODE# 191 | SCORE:     10 | MEMORY_LENGTH:       4078 | EPSILON:  0.390
# EPISODE# 192 | SCORE:     11 | MEMORY_LENGTH:       4091 | EPSILON:  0.388
# EPISODE# 193 | SCORE:      8 | MEMORY_LENGTH:       4101 | EPSILON:  0.386
# EPISODE# 194 | SCORE:      9 | MEMORY_LENGTH:       4112 | EPSILON:  0.384
# EPISODE# 195 | SCORE:      9 | MEMORY_LENGTH:       4123 | EPSILON:  0.381
# EPISODE# 196 | SCORE:      7 | MEMORY_LENGTH:       4132 | EPSILON:  0.380
# EPISODE# 197 | SCORE:     15 | MEMORY_LENGTH:       4149 | EPSILON:  0.376
# EPISODE# 198 | SCORE:     14 | MEMORY_LENGTH:       4165 | EPSILON:  0.373
# EPISODE# 199 | SCORE:     10 | MEMORY_LENGTH:       4177 | EPSILON:  0.371
# EPISODE# 200 | SCORE:     10 | MEMORY_LENGTH:       4189 | EPSILON:  0.368
# EPISODE# 201 | SCORE:     11 | MEMORY_LENGTH:       4202 | EPSILON:  0.366
# EPISODE# 202 | SCORE:     11 | MEMORY_LENGTH:       4215 | EPSILON:  0.363
# EPISODE# 203 | SCORE:      9 | MEMORY_LENGTH:       4226 | EPSILON:  0.361
# EPISODE# 204 | SCORE:     12 | MEMORY_LENGTH:       4240 | EPSILON:  0.358
# EPISODE# 205 | SCORE:     26 | MEMORY_LENGTH:       4268 | EPSILON:  0.353
# EPISODE# 206 | SCORE:      9 | MEMORY_LENGTH:       4279 | EPSILON:  0.351
# EPISODE# 207 | SCORE:      7 | MEMORY_LENGTH:       4288 | EPSILON:  0.349
# EPISODE# 208 | SCORE:     11 | MEMORY_LENGTH:       4301 | EPSILON:  0.346
# EPISODE# 209 | SCORE:      9 | MEMORY_LENGTH:       4312 | EPSILON:  0.344
# EPISODE# 210 | SCORE:    175 | MEMORY_LENGTH:       4489 | EPSILON:  0.309
# EPISODE# 211 | SCORE:     25 | MEMORY_LENGTH:       4516 | EPSILON:  0.304
# EPISODE# 212 | SCORE:     34 | MEMORY_LENGTH:       4552 | EPSILON:  0.297
# EPISODE# 213 | SCORE:     77 | MEMORY_LENGTH:       4631 | EPSILON:  0.281
# EPISODE# 214 | SCORE:     23 | MEMORY_LENGTH:       4656 | EPSILON:  0.276
# EPISODE# 215 | SCORE:     23 | MEMORY_LENGTH:       4681 | EPSILON:  0.271
# EPISODE# 216 | SCORE:     35 | MEMORY_LENGTH:       4718 | EPSILON:  0.264
# EPISODE# 217 | SCORE:     13 | MEMORY_LENGTH:       4733 | EPSILON:  0.261
# EPISODE# 218 | SCORE:     27 | MEMORY_LENGTH:       4762 | EPSILON:  0.255
# EPISODE# 219 | SCORE:     11 | MEMORY_LENGTH:       4775 | EPSILON:  0.252
# EPISODE# 220 | SCORE:     25 | MEMORY_LENGTH:       4802 | EPSILON:  0.247
# EPISODE# 221 | SCORE:     37 | MEMORY_LENGTH:       4841 | EPSILON:  0.239
# EPISODE# 222 | SCORE:     25 | MEMORY_LENGTH:       4868 | EPSILON:  0.234
# EPISODE# 223 | SCORE:     30 | MEMORY_LENGTH:       4900 | EPSILON:  0.228
# EPISODE# 224 | SCORE:     12 | MEMORY_LENGTH:       4914 | EPSILON:  0.225
# EPISODE# 225 | SCORE:     10 | MEMORY_LENGTH:       4926 | EPSILON:  0.222
# EPISODE# 226 | SCORE:     27 | MEMORY_LENGTH:       4955 | EPSILON:  0.217
# EPISODE# 227 | SCORE:      8 | MEMORY_LENGTH:       4965 | EPSILON:  0.215
# EPISODE# 228 | SCORE:     22 | MEMORY_LENGTH:       4989 | EPSILON:  0.210
# EPISODE# 229 | SCORE:     15 | MEMORY_LENGTH:       5006 | EPSILON:  0.207
# EPISODE# 230 | SCORE:     45 | MEMORY_LENGTH:       5053 | EPSILON:  0.197
# EPISODE# 231 | SCORE:      9 | MEMORY_LENGTH:       5064 | EPSILON:  0.195
# EPISODE# 232 | SCORE:     32 | MEMORY_LENGTH:       5098 | EPSILON:  0.188
# EPISODE# 233 | SCORE:     29 | MEMORY_LENGTH:       5129 | EPSILON:  0.182
# EPISODE# 234 | SCORE:     14 | MEMORY_LENGTH:       5145 | EPSILON:  0.179
# EPISODE# 235 | SCORE:     27 | MEMORY_LENGTH:       5174 | EPSILON:  0.173
# EPISODE# 236 | SCORE:     30 | MEMORY_LENGTH:       5206 | EPSILON:  0.167
# EPISODE# 237 | SCORE:     44 | MEMORY_LENGTH:       5252 | EPSILON:  0.158
# EPISODE# 238 | SCORE:     10 | MEMORY_LENGTH:       5264 | EPSILON:  0.156
# EPISODE# 239 | SCORE:     36 | MEMORY_LENGTH:       5302 | EPSILON:  0.148
# EPISODE# 240 | SCORE:     36 | MEMORY_LENGTH:       5340 | EPSILON:  0.140
# EPISODE# 241 | SCORE:     10 | MEMORY_LENGTH:       5352 | EPSILON:  0.138
# EPISODE# 242 | SCORE:     49 | MEMORY_LENGTH:       5403 | EPSILON:  0.128
# EPISODE# 243 | SCORE:     30 | MEMORY_LENGTH:       5435 | EPSILON:  0.122
# EPISODE# 244 | SCORE:     45 | MEMORY_LENGTH:       5482 | EPSILON:  0.112
# EPISODE# 245 | SCORE:     12 | MEMORY_LENGTH:       5496 | EPSILON:  0.110
# EPISODE# 246 | SCORE:     15 | MEMORY_LENGTH:       5513 | EPSILON:  0.106
# EPISODE# 247 | SCORE:     26 | MEMORY_LENGTH:       5541 | EPSILON:  0.101
# EPISODE# 248 | SCORE:     22 | MEMORY_LENGTH:       5565 | EPSILON:  0.096
# EPISODE# 249 | SCORE:     62 | MEMORY_LENGTH:       5629 | EPSILON:  0.083
# EPISODE# 250 | SCORE:     25 | MEMORY_LENGTH:       5656 | EPSILON:  0.078
# EPISODE# 251 | SCORE:     27 | MEMORY_LENGTH:       5685 | EPSILON:  0.072
# EPISODE# 252 | SCORE:     24 | MEMORY_LENGTH:       5711 | EPSILON:  0.067
# EPISODE# 253 | SCORE:     15 | MEMORY_LENGTH:       5728 | EPSILON:  0.064
# EPISODE# 254 | SCORE:     10 | MEMORY_LENGTH:       5740 | EPSILON:  0.061
# EPISODE# 255 | SCORE:     23 | MEMORY_LENGTH:       5765 | EPSILON:  0.056
# EPISODE# 256 | SCORE:     35 | MEMORY_LENGTH:       5802 | EPSILON:  0.049
# EPISODE# 257 | SCORE:     25 | MEMORY_LENGTH:       5829 | EPSILON:  0.044
# EPISODE# 258 | SCORE:     10 | MEMORY_LENGTH:       5841 | EPSILON:  0.041
# EPISODE# 259 | SCORE:     35 | MEMORY_LENGTH:       5878 | EPSILON:  0.034
# EPISODE# 260 | SCORE:     27 | MEMORY_LENGTH:       5907 | EPSILON:  0.028
# EPISODE# 261 | SCORE:     24 | MEMORY_LENGTH:       5933 | EPSILON:  0.023
# EPISODE# 262 | SCORE:     24 | MEMORY_LENGTH:       5959 | EPSILON:  0.018
# EPISODE# 263 | SCORE:     25 | MEMORY_LENGTH:       5986 | EPSILON:  0.013
# EPISODE# 264 | SCORE:     42 | MEMORY_LENGTH:       6030 | EPSILON:  0.010
# EPISODE# 265 | SCORE:     25 | MEMORY_LENGTH:       6057 | EPSILON:  0.010
# EPISODE# 266 | SCORE:     25 | MEMORY_LENGTH:       6084 | EPSILON:  0.010
# EPISODE# 267 | SCORE:     25 | MEMORY_LENGTH:       6111 | EPSILON:  0.010
# EPISODE# 268 | SCORE:     25 | MEMORY_LENGTH:       6138 | EPSILON:  0.010
# EPISODE# 269 | SCORE:     24 | MEMORY_LENGTH:       6164 | EPSILON:  0.010
# EPISODE# 270 | SCORE:     23 | MEMORY_LENGTH:       6189 | EPSILON:  0.010
# EPISODE# 271 | SCORE:     22 | MEMORY_LENGTH:       6213 | EPSILON:  0.010
# EPISODE# 272 | SCORE:     41 | MEMORY_LENGTH:       6256 | EPSILON:  0.010
# EPISODE# 273 | SCORE:     30 | MEMORY_LENGTH:       6288 | EPSILON:  0.010
# EPISODE# 274 | SCORE:     28 | MEMORY_LENGTH:       6318 | EPSILON:  0.010
# EPISODE# 275 | SCORE:     42 | MEMORY_LENGTH:       6362 | EPSILON:  0.010
# EPISODE# 276 | SCORE:     37 | MEMORY_LENGTH:       6401 | EPSILON:  0.010
# EPISODE# 277 | SCORE:     43 | MEMORY_LENGTH:       6446 | EPSILON:  0.010
# EPISODE# 278 | SCORE:     26 | MEMORY_LENGTH:       6474 | EPSILON:  0.010
# EPISODE# 279 | SCORE:     37 | MEMORY_LENGTH:       6513 | EPSILON:  0.010
# EPISODE# 280 | SCORE:     43 | MEMORY_LENGTH:       6558 | EPSILON:  0.010
# EPISODE# 281 | SCORE:     23 | MEMORY_LENGTH:       6583 | EPSILON:  0.010
# EPISODE# 282 | SCORE:     40 | MEMORY_LENGTH:       6625 | EPSILON:  0.010
# EPISODE# 283 | SCORE:     25 | MEMORY_LENGTH:       6652 | EPSILON:  0.010
# EPISODE# 284 | SCORE:      9 | MEMORY_LENGTH:       6663 | EPSILON:  0.010
# EPISODE# 285 | SCORE:     42 | MEMORY_LENGTH:       6707 | EPSILON:  0.010
# EPISODE# 286 | SCORE:     28 | MEMORY_LENGTH:       6737 | EPSILON:  0.010
# EPISODE# 287 | SCORE:     41 | MEMORY_LENGTH:       6780 | EPSILON:  0.010
# EPISODE# 288 | SCORE:     39 | MEMORY_LENGTH:       6821 | EPSILON:  0.010
# EPISODE# 289 | SCORE:     26 | MEMORY_LENGTH:       6849 | EPSILON:  0.010
# EPISODE# 290 | SCORE:     10 | MEMORY_LENGTH:       6861 | EPSILON:  0.010
# EPISODE# 291 | SCORE:     26 | MEMORY_LENGTH:       6889 | EPSILON:  0.010
# EPISODE# 292 | SCORE:     42 | MEMORY_LENGTH:       6933 | EPSILON:  0.010
# EPISODE# 293 | SCORE:     25 | MEMORY_LENGTH:       6960 | EPSILON:  0.010
# EPISODE# 294 | SCORE:     10 | MEMORY_LENGTH:       6972 | EPSILON:  0.010
# EPISODE# 295 | SCORE:     26 | MEMORY_LENGTH:       7000 | EPSILON:  0.010
# EPISODE# 296 | SCORE:     10 | MEMORY_LENGTH:       7012 | EPSILON:  0.010
# EPISODE# 297 | SCORE:     28 | MEMORY_LENGTH:       7042 | EPSILON:  0.010
# EPISODE# 298 | SCORE:     41 | MEMORY_LENGTH:       7085 | EPSILON:  0.010
# EPISODE# 299 | SCORE:     41 | MEMORY_LENGTH:       7128 | EPSILON:  0.010
# EPISODE# 300 | SCORE:     26 | MEMORY_LENGTH:       7156 | EPSILON:  0.010
# EPISODE# 301 | SCORE:     95 | MEMORY_LENGTH:       7253 | EPSILON:  0.010
# EPISODE# 302 | SCORE:    107 | MEMORY_LENGTH:       7362 | EPSILON:  0.010
# EPISODE# 303 | SCORE:    123 | MEMORY_LENGTH:       7487 | EPSILON:  0.010
# EPISODE# 304 | SCORE:     55 | MEMORY_LENGTH:       7544 | EPSILON:  0.010
# EPISODE# 305 | SCORE:     85 | MEMORY_LENGTH:       7631 | EPSILON:  0.010
# EPISODE# 306 | SCORE:     81 | MEMORY_LENGTH:       7714 | EPSILON:  0.010
# EPISODE# 307 | SCORE:     76 | MEMORY_LENGTH:       7792 | EPSILON:  0.010
# EPISODE# 308 | SCORE:     68 | MEMORY_LENGTH:       7862 | EPSILON:  0.010
# EPISODE# 309 | SCORE:     66 | MEMORY_LENGTH:       7930 | EPSILON:  0.010
# EPISODE# 310 | SCORE:    120 | MEMORY_LENGTH:       8052 | EPSILON:  0.010
# EPISODE# 311 | SCORE:     80 | MEMORY_LENGTH:       8134 | EPSILON:  0.010
# EPISODE# 312 | SCORE:     79 | MEMORY_LENGTH:       8215 | EPSILON:  0.010
# EPISODE# 313 | SCORE:     79 | MEMORY_LENGTH:       8296 | EPSILON:  0.010
# EPISODE# 314 | SCORE:     52 | MEMORY_LENGTH:       8350 | EPSILON:  0.010
# EPISODE# 315 | SCORE:    124 | MEMORY_LENGTH:       8476 | EPSILON:  0.010
# EPISODE# 316 | SCORE:     40 | MEMORY_LENGTH:       8518 | EPSILON:  0.010
# EPISODE# 317 | SCORE:     28 | MEMORY_LENGTH:       8548 | EPSILON:  0.010
# EPISODE# 318 | SCORE:     62 | MEMORY_LENGTH:       8612 | EPSILON:  0.010
# EPISODE# 319 | SCORE:     40 | MEMORY_LENGTH:       8654 | EPSILON:  0.010
# EPISODE# 320 | SCORE:     29 | MEMORY_LENGTH:       8685 | EPSILON:  0.010
# EPISODE# 321 | SCORE:     35 | MEMORY_LENGTH:       8722 | EPSILON:  0.010
# EPISODE# 322 | SCORE:     77 | MEMORY_LENGTH:       8801 | EPSILON:  0.010
# EPISODE# 323 | SCORE:     30 | MEMORY_LENGTH:       8833 | EPSILON:  0.010
# EPISODE# 324 | SCORE:     31 | MEMORY_LENGTH:       8866 | EPSILON:  0.010
# EPISODE# 325 | SCORE:     55 | MEMORY_LENGTH:       8923 | EPSILON:  0.010
# EPISODE# 326 | SCORE:     55 | MEMORY_LENGTH:       8980 | EPSILON:  0.010
# EPISODE# 327 | SCORE:     36 | MEMORY_LENGTH:       9018 | EPSILON:  0.010
# EPISODE# 328 | SCORE:     68 | MEMORY_LENGTH:       9088 | EPSILON:  0.010
# EPISODE# 329 | SCORE:     35 | MEMORY_LENGTH:       9125 | EPSILON:  0.010
# EPISODE# 330 | SCORE:     67 | MEMORY_LENGTH:       9194 | EPSILON:  0.010
# EPISODE# 331 | SCORE:     38 | MEMORY_LENGTH:       9234 | EPSILON:  0.010
# EPISODE# 332 | SCORE:     43 | MEMORY_LENGTH:       9279 | EPSILON:  0.010
# EPISODE# 333 | SCORE:     71 | MEMORY_LENGTH:       9352 | EPSILON:  0.010
# EPISODE# 334 | SCORE:     64 | MEMORY_LENGTH:       9418 | EPSILON:  0.010
# EPISODE# 335 | SCORE:     66 | MEMORY_LENGTH:       9486 | EPSILON:  0.010
# EPISODE# 336 | SCORE:     75 | MEMORY_LENGTH:       9563 | EPSILON:  0.010
# EPISODE# 337 | SCORE:     37 | MEMORY_LENGTH:       9602 | EPSILON:  0.010
# EPISODE# 338 | SCORE:     54 | MEMORY_LENGTH:       9658 | EPSILON:  0.010
# EPISODE# 339 | SCORE:     60 | MEMORY_LENGTH:       9720 | EPSILON:  0.010
# EPISODE# 340 | SCORE:     35 | MEMORY_LENGTH:       9757 | EPSILON:  0.010
# EPISODE# 341 | SCORE:     60 | MEMORY_LENGTH:       9819 | EPSILON:  0.010
# EPISODE# 342 | SCORE:     56 | MEMORY_LENGTH:       9877 | EPSILON:  0.010
# EPISODE# 343 | SCORE:     56 | MEMORY_LENGTH:       9935 | EPSILON:  0.010
# EPISODE# 344 | SCORE:     52 | MEMORY_LENGTH:       9989 | EPSILON:  0.010
# EPISODE# 345 | SCORE:     60 | MEMORY_LENGTH:      10051 | EPSILON:  0.010
# EPISODE# 346 | SCORE:     34 | MEMORY_LENGTH:      10087 | EPSILON:  0.010
# EPISODE# 347 | SCORE:     55 | MEMORY_LENGTH:      10144 | EPSILON:  0.010
# EPISODE# 348 | SCORE:     76 | MEMORY_LENGTH:      10222 | EPSILON:  0.010
# EPISODE# 349 | SCORE:     35 | MEMORY_LENGTH:      10259 | EPSILON:  0.010
# EPISODE# 350 | SCORE:     58 | MEMORY_LENGTH:      10319 | EPSILON:  0.010
# EPISODE# 351 | SCORE:     32 | MEMORY_LENGTH:      10353 | EPSILON:  0.010
# EPISODE# 352 | SCORE:     70 | MEMORY_LENGTH:      10425 | EPSILON:  0.010
# EPISODE# 353 | SCORE:     58 | MEMORY_LENGTH:      10485 | EPSILON:  0.010
# EPISODE# 354 | SCORE:     55 | MEMORY_LENGTH:      10542 | EPSILON:  0.010
# EPISODE# 355 | SCORE:     78 | MEMORY_LENGTH:      10622 | EPSILON:  0.010
# EPISODE# 356 | SCORE:     30 | MEMORY_LENGTH:      10654 | EPSILON:  0.010
# EPISODE# 357 | SCORE:     34 | MEMORY_LENGTH:      10690 | EPSILON:  0.010
# EPISODE# 358 | SCORE:     60 | MEMORY_LENGTH:      10752 | EPSILON:  0.010
# EPISODE# 359 | SCORE:     87 | MEMORY_LENGTH:      10841 | EPSILON:  0.010
# EPISODE# 360 | SCORE:     88 | MEMORY_LENGTH:      10931 | EPSILON:  0.010
# EPISODE# 361 | SCORE:     76 | MEMORY_LENGTH:      11009 | EPSILON:  0.010
# EPISODE# 362 | SCORE:     35 | MEMORY_LENGTH:      11046 | EPSILON:  0.010
# EPISODE# 363 | SCORE:     36 | MEMORY_LENGTH:      11084 | EPSILON:  0.010
# EPISODE# 364 | SCORE:     37 | MEMORY_LENGTH:      11123 | EPSILON:  0.010
# EPISODE# 365 | SCORE:     32 | MEMORY_LENGTH:      11157 | EPSILON:  0.010
# EPISODE# 366 | SCORE:     81 | MEMORY_LENGTH:      11240 | EPSILON:  0.010
# EPISODE# 367 | SCORE:     83 | MEMORY_LENGTH:      11325 | EPSILON:  0.010
# EPISODE# 368 | SCORE:     56 | MEMORY_LENGTH:      11383 | EPSILON:  0.010
# EPISODE# 369 | SCORE:     82 | MEMORY_LENGTH:      11467 | EPSILON:  0.010
# EPISODE# 370 | SCORE:     58 | MEMORY_LENGTH:      11527 | EPSILON:  0.010
# EPISODE# 371 | SCORE:     61 | MEMORY_LENGTH:      11590 | EPSILON:  0.010
# EPISODE# 372 | SCORE:     57 | MEMORY_LENGTH:      11649 | EPSILON:  0.010
# EPISODE# 373 | SCORE:     93 | MEMORY_LENGTH:      11744 | EPSILON:  0.010
# EPISODE# 374 | SCORE:    116 | MEMORY_LENGTH:      11862 | EPSILON:  0.010
# EPISODE# 375 | SCORE:     65 | MEMORY_LENGTH:      11929 | EPSILON:  0.010
# EPISODE# 376 | SCORE:     86 | MEMORY_LENGTH:      12017 | EPSILON:  0.010
# EPISODE# 377 | SCORE:     69 | MEMORY_LENGTH:      12088 | EPSILON:  0.010
# EPISODE# 378 | SCORE:     36 | MEMORY_LENGTH:      12126 | EPSILON:  0.010
# EPISODE# 379 | SCORE:     62 | MEMORY_LENGTH:      12190 | EPSILON:  0.010
# EPISODE# 380 | SCORE:     62 | MEMORY_LENGTH:      12254 | EPSILON:  0.010
# EPISODE# 381 | SCORE:     80 | MEMORY_LENGTH:      12336 | EPSILON:  0.010
# EPISODE# 382 | SCORE:     34 | MEMORY_LENGTH:      12372 | EPSILON:  0.010
# EPISODE# 383 | SCORE:     83 | MEMORY_LENGTH:      12457 | EPSILON:  0.010
# EPISODE# 384 | SCORE:     60 | MEMORY_LENGTH:      12519 | EPSILON:  0.010
# EPISODE# 385 | SCORE:    117 | MEMORY_LENGTH:      12638 | EPSILON:  0.010
# EPISODE# 386 | SCORE:     59 | MEMORY_LENGTH:      12699 | EPSILON:  0.010
# EPISODE# 387 | SCORE:     58 | MEMORY_LENGTH:      12759 | EPSILON:  0.010
# EPISODE# 388 | SCORE:     39 | MEMORY_LENGTH:      12800 | EPSILON:  0.010
# EPISODE# 389 | SCORE:     58 | MEMORY_LENGTH:      12860 | EPSILON:  0.010
# EPISODE# 390 | SCORE:     10 | MEMORY_LENGTH:      12872 | EPSILON:  0.010
# EPISODE# 391 | SCORE:    133 | MEMORY_LENGTH:      13007 | EPSILON:  0.010
# EPISODE# 392 | SCORE:     35 | MEMORY_LENGTH:      13044 | EPSILON:  0.010
# EPISODE# 393 | SCORE:     54 | MEMORY_LENGTH:      13100 | EPSILON:  0.010
# EPISODE# 394 | SCORE:     57 | MEMORY_LENGTH:      13159 | EPSILON:  0.010
# EPISODE# 395 | SCORE:    113 | MEMORY_LENGTH:      13274 | EPSILON:  0.010
# EPISODE# 396 | SCORE:     64 | MEMORY_LENGTH:      13340 | EPSILON:  0.010
# EPISODE# 397 | SCORE:     58 | MEMORY_LENGTH:      13400 | EPSILON:  0.010
# EPISODE# 398 | SCORE:    107 | MEMORY_LENGTH:      13509 | EPSILON:  0.010
# EPISODE# 399 | SCORE:     64 | MEMORY_LENGTH:      13575 | EPSILON:  0.010
# EPISODE# 400 | SCORE:    111 | MEMORY_LENGTH:      13688 | EPSILON:  0.010
# EPISODE# 401 | SCORE:    170 | MEMORY_LENGTH:      13860 | EPSILON:  0.010
# EPISODE# 402 | SCORE:    153 | MEMORY_LENGTH:      14015 | EPSILON:  0.010
# EPISODE# 403 | SCORE:    126 | MEMORY_LENGTH:      14143 | EPSILON:  0.010
# EPISODE# 404 | SCORE:    142 | MEMORY_LENGTH:      14287 | EPSILON:  0.010
# EPISODE# 405 | SCORE:    128 | MEMORY_LENGTH:      14417 | EPSILON:  0.010
# EPISODE# 406 | SCORE:    137 | MEMORY_LENGTH:      14556 | EPSILON:  0.010
# EPISODE# 407 | SCORE:    127 | MEMORY_LENGTH:      14685 | EPSILON:  0.010
# EPISODE# 408 | SCORE:    133 | MEMORY_LENGTH:      14820 | EPSILON:  0.010
# EPISODE# 409 | SCORE:    120 | MEMORY_LENGTH:      14942 | EPSILON:  0.010
# EPISODE# 410 | SCORE:    125 | MEMORY_LENGTH:      15069 | EPSILON:  0.010
# EPISODE# 411 | SCORE:    131 | MEMORY_LENGTH:      15202 | EPSILON:  0.010
# EPISODE# 412 | SCORE:    131 | MEMORY_LENGTH:      15335 | EPSILON:  0.010
# EPISODE# 413 | SCORE:    129 | MEMORY_LENGTH:      15466 | EPSILON:  0.010
# EPISODE# 414 | SCORE:    121 | MEMORY_LENGTH:      15589 | EPSILON:  0.010
# EPISODE# 415 | SCORE:    131 | MEMORY_LENGTH:      15722 | EPSILON:  0.010
# EPISODE# 416 | SCORE:    144 | MEMORY_LENGTH:      15868 | EPSILON:  0.010
# EPISODE# 417 | SCORE:    132 | MEMORY_LENGTH:      16002 | EPSILON:  0.010
# EPISODE# 418 | SCORE:    138 | MEMORY_LENGTH:      16142 | EPSILON:  0.010
# EPISODE# 419 | SCORE:    111 | MEMORY_LENGTH:      16255 | EPSILON:  0.010
# EPISODE# 420 | SCORE:    118 | MEMORY_LENGTH:      16375 | EPSILON:  0.010
# EPISODE# 421 | SCORE:    128 | MEMORY_LENGTH:      16505 | EPSILON:  0.010
# EPISODE# 422 | SCORE:    131 | MEMORY_LENGTH:      16638 | EPSILON:  0.010
# EPISODE# 423 | SCORE:    133 | MEMORY_LENGTH:      16773 | EPSILON:  0.010
# EPISODE# 424 | SCORE:    123 | MEMORY_LENGTH:      16898 | EPSILON:  0.010
# EPISODE# 425 | SCORE:    117 | MEMORY_LENGTH:      17017 | EPSILON:  0.010
# EPISODE# 426 | SCORE:     51 | MEMORY_LENGTH:      17070 | EPSILON:  0.010
# EPISODE# 427 | SCORE:    135 | MEMORY_LENGTH:      17207 | EPSILON:  0.010
# EPISODE# 428 | SCORE:    124 | MEMORY_LENGTH:      17333 | EPSILON:  0.010
# EPISODE# 429 | SCORE:     11 | MEMORY_LENGTH:      17346 | EPSILON:  0.010
# EPISODE# 430 | SCORE:    132 | MEMORY_LENGTH:      17480 | EPSILON:  0.010
# EPISODE# 431 | SCORE:    131 | MEMORY_LENGTH:      17613 | EPSILON:  0.010
# EPISODE# 432 | SCORE:    119 | MEMORY_LENGTH:      17734 | EPSILON:  0.010
# EPISODE# 433 | SCORE:    107 | MEMORY_LENGTH:      17843 | EPSILON:  0.010
# EPISODE# 434 | SCORE:    140 | MEMORY_LENGTH:      17985 | EPSILON:  0.010
# EPISODE# 435 | SCORE:    119 | MEMORY_LENGTH:      18106 | EPSILON:  0.010
# EPISODE# 436 | SCORE:    122 | MEMORY_LENGTH:      18230 | EPSILON:  0.010
# EPISODE# 437 | SCORE:    120 | MEMORY_LENGTH:      18352 | EPSILON:  0.010
# EPISODE# 438 | SCORE:    115 | MEMORY_LENGTH:      18469 | EPSILON:  0.010
# EPISODE# 439 | SCORE:    113 | MEMORY_LENGTH:      18584 | EPSILON:  0.010
# EPISODE# 440 | SCORE:    101 | MEMORY_LENGTH:      18687 | EPSILON:  0.010
# EPISODE# 441 | SCORE:    119 | MEMORY_LENGTH:      18808 | EPSILON:  0.010
# EPISODE# 442 | SCORE:    117 | MEMORY_LENGTH:      18927 | EPSILON:  0.010
# EPISODE# 443 | SCORE:    102 | MEMORY_LENGTH:      19031 | EPSILON:  0.010
# EPISODE# 444 | SCORE:    109 | MEMORY_LENGTH:      19142 | EPSILON:  0.010
# EPISODE# 445 | SCORE:    114 | MEMORY_LENGTH:      19258 | EPSILON:  0.010
# EPISODE# 446 | SCORE:     96 | MEMORY_LENGTH:      19356 | EPSILON:  0.010
# EPISODE# 447 | SCORE:    124 | MEMORY_LENGTH:      19482 | EPSILON:  0.010
# EPISODE# 448 | SCORE:    107 | MEMORY_LENGTH:      19591 | EPSILON:  0.010
# EPISODE# 449 | SCORE:    132 | MEMORY_LENGTH:      19725 | EPSILON:  0.010
# EPISODE# 450 | SCORE:     31 | MEMORY_LENGTH:      19758 | EPSILON:  0.010
# EPISODE# 451 | SCORE:    107 | MEMORY_LENGTH:      19867 | EPSILON:  0.010
# EPISODE# 452 | SCORE:    106 | MEMORY_LENGTH:      19975 | EPSILON:  0.010
# EPISODE# 453 | SCORE:    133 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 454 | SCORE:    125 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 455 | SCORE:    107 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 456 | SCORE:    132 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 457 | SCORE:    118 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 458 | SCORE:    103 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 459 | SCORE:    109 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 460 | SCORE:    125 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 461 | SCORE:     99 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 462 | SCORE:    138 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 463 | SCORE:    110 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 464 | SCORE:    133 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 465 | SCORE:     34 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 466 | SCORE:    124 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 467 | SCORE:    132 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 468 | SCORE:    103 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 469 | SCORE:     38 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 470 | SCORE:    112 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 471 | SCORE:    111 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 472 | SCORE:     42 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 473 | SCORE:    109 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 474 | SCORE:    113 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 475 | SCORE:    122 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 476 | SCORE:    128 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 477 | SCORE:    118 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 478 | SCORE:    135 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 479 | SCORE:    109 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 480 | SCORE:    149 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 481 | SCORE:    119 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 482 | SCORE:    125 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 483 | SCORE:    135 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 484 | SCORE:    120 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 485 | SCORE:    114 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 486 | SCORE:    135 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 487 | SCORE:    121 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 488 | SCORE:    127 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 489 | SCORE:    138 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 490 | SCORE:     38 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 491 | SCORE:    133 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 492 | SCORE:    120 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 493 | SCORE:    125 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 494 | SCORE:    110 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 495 | SCORE:    139 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 496 | SCORE:    132 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 497 | SCORE:    107 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 498 | SCORE:    122 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
# EPISODE# 499 | SCORE:    112 | MEMORY_LENGTH:      20000 | EPSILON:  0.010
