# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE          = 32
LR                  = 1e-3  # learning rate
EPSILON             = 0.9   # greedy policy
GAMMA               = 0.9   # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY     = 2000
SEGREGATION_BIAS    = 6     # no. of non-terminal memories in batch

# %%
env = gym.make('CartPole-v0')
# env = env.unwrapped
env.seed(seed);

# %%
N_ACTIONS   = env.action_space.n
N_STATES    = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter  = 0 # for target updating
        
        self.good_memory_counter = 0 # for storing non-terminal memories
        self.good_memory         = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.bad_memory_counter  = 0 # for storing terminal memories
        self.bad_memory          = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.optimizer           = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func           = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        if r > 0: #non-terminal rewards
            # replace the old memory with new memory
            index = self.good_memory_counter % int(MEMORY_CAPACITY/2)
            self.good_memory[index, :] = transition
            self.good_memory_counter += 1
        
        else: #terminal rewards
            # replace the old memory with new memory
            index = self.bad_memory_counter % int(MEMORY_CAPACITY/2)
            self.bad_memory[index, :] = transition
            self.bad_memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        good_sample_index = np.random.choice(int(MEMORY_CAPACITY/2), int(SEGREGATION_BIAS))
        bad_sample_index  = np.random.choice(int(MEMORY_CAPACITY/2), int(BATCH_SIZE-SEGREGATION_BIAS))

        b_good_memory = self.good_memory[good_sample_index, :]
        b_bad_memory  = self.bad_memory[bad_sample_index, :]
        b_memory      = np.vstack((b_good_memory,b_bad_memory))
        
        b_s  = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a  = torch.LongTensor( b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r  = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval   = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next   = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss     = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = int(MEMORY_CAPACITY/2) + 1000

# %%
print('\nCollecting experience...')
REMEMBER_LIMIT = 200
TIMESTEP_LIMIT = 200
total_time_steps = 0
ep_r_rec = []
time_rec = []
flag = True
learn_start = 0
upgrade_metric = 198
upgrade_flag = False
upgrade_counter = 0
for i_episode in range(NO_OF_EPISODES):
       
    s = env.reset()
    ep_r = 0
    time_steps = 0
    stop_remember = False
    while True:
#         env.render()
        time_steps += 1
        total_time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)
        
        if time_steps > REMEMBER_LIMIT:
            stop_remember = True
        
        if (stop_remember == False):
            dqn.store_transition(s, a, r, s_)
        
        if time_steps > TIMESTEP_LIMIT:
            done = True
        
        if done:
            r = -1
            if time_steps >= TIMESTEP_LIMIT:
                r = 1
            dqn.store_transition(s, a, r, s_)
        
        ep_r += r
        if dqn.good_memory_counter > MEMORY_CAPACITY/2 and dqn.bad_memory_counter > MEMORY_CAPACITY/2:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                learn_start = i_episode
                flag = False
        
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 196:
                print('EPISODE: {:4d}  |  TIME_STEPS: {:5d}  |  EPSILON: {:3.2f} | TOTAL TIME_STEPS: {:10d} '.format(i_episode, time_steps, EPSILON, total_time_steps))
            
            break
        s = s_
    
    #if mean of episode lenght of last 10 episodes is greater than upgrade_metric
    if np.mean(time_rec[-10:]) > upgrade_metric:
        upgrade_counter += 1
    else:
        upgrade_counter = 0
        
    if upgrade_counter > 110:
        upgrade_counter = 0
        print("Upgrading @ EPISODE: ", i_episode)
#         upgrade_metric *= 2
#         LR *= 0.1
        EPSILON += 0.02
# Out:
# Collecting experience...
# Learning starts from EPISODE:  1000
# EPISODE: 1045  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      12939
# EPISODE: 1051  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      13954
# EPISODE: 1054  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      14499
# EPISODE: 1059  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      15331
# EPISODE: 1064  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      16216
# EPISODE: 1065  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      16416
# EPISODE: 1066  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      16616
# EPISODE: 1068  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      16972
# EPISODE: 1106  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      23342
# EPISODE: 1125  |  TIME_STEPS:   197  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      26683
# EPISODE: 1126  |  TIME_STEPS:   199  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      26882
# EPISODE: 1138  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      29049
# EPISODE: 1140  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      29431
# EPISODE: 1141  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      29631
# EPISODE: 1142  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      29831
# EPISODE: 1144  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      30215
# EPISODE: 1145  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      30415
# EPISODE: 1146  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      30615
# EPISODE: 1148  |  TIME_STEPS:   197  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      31004
# EPISODE: 1150  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      31387
# EPISODE: 1151  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      31587
# EPISODE: 1152  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      31787
# EPISODE: 1159  |  TIME_STEPS:   198  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      33071
# EPISODE: 1160  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      33271
# EPISODE: 1174  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      35779
# EPISODE: 1179  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      36693
# EPISODE: 1180  |  TIME_STEPS:   197  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      36890
# EPISODE: 1195  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      39604
# EPISODE: 1200  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      40558
# EPISODE: 1201  |  TIME_STEPS:   197  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      40755
# EPISODE: 1204  |  TIME_STEPS:   197  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      41335
# EPISODE: 1206  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      41730
# EPISODE: 1210  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      42487
# EPISODE: 1211  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      42687
# EPISODE: 1216  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      43650
# EPISODE: 1217  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      43850
# EPISODE: 1219  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:      44241
# EPISODE: 1221  |  TIME_STEPS:   200  |  EPSILON: 0.90 | TOTAL TIME_STEPS:
|  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     186895
# EPISODE: 1939  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     187095
# EPISODE: 1940  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     187295
# EPISODE: 1941  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     187495
# EPISODE: 1942  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     187695
# EPISODE: 1943  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     187895
# EPISODE: 1944  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     188095
# EPISODE: 1945  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     188295
# EPISODE: 1946  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     188495
# EPISODE: 1947  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     188695
# EPISODE: 1948  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     188895
# EPISODE: 1949  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     189095
# EPISODE: 1950  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     189295
# EPISODE: 1951  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     189495
# EPISODE: 1952  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     189695
# EPISODE: 1953  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     189895
# EPISODE: 1954  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     190095
# EPISODE: 1955  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     190295
# EPISODE: 1956  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     190495
# EPISODE: 1957  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     190695
# EPISODE: 1958  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     190895
# EPISODE: 1959  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     191095
# EPISODE: 1960  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     191295
# EPISODE: 1961  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     191495
# EPISODE: 1962  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     191695
# EPISODE: 1963  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     191895
# EPISODE: 1964  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     192095
# EPISODE: 1965  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     192295
# EPISODE: 1966  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     192495
# EPISODE: 1967  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     192695
# EPISODE: 1968  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     192895
# EPISODE: 1969  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     193095
# EPISODE: 1970  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     193295
# EPISODE: 1971  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     193495
# EPISODE: 1972  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     193695
# EPISODE: 1973  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     193895
# EPISODE: 1974  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     194095
# EPISODE: 1975  |  TIME_STEPS:   200  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     194295
# Upgrading @ EPISODE:  1975
# EPISODE: 1976  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     194495
# EPISODE: 1977  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     194695
# EPISODE: 1978  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     194895
# EPISODE: 1979  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     195095
# EPISODE: 1980  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     195295
# EPISODE: 1981  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     195495
# EPISODE: 1982  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     195695
# EPISODE: 1983  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     195895
# EPISODE: 1984  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     196095
# EPISODE: 1985  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     196295
# EPISODE: 1986  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     196495
# EPISODE: 1987  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     196695
# EPISODE: 1988  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     196895
# EPISODE: 1989  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     197095
# EPISODE: 1990  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     197295
# EPISODE: 1991  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     197495
# EPISODE: 1992  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     197695
# EPISODE: 1993  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     197895
# EPISODE: 1994  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     198095
# EPISODE: 1995  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     198295
# EPISODE: 1996  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     198495
# EPISODE: 1997  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     198695
# EPISODE: 1998  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     198895
# EPISODE: 1999  |  TIME_STEPS:   200  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     199095

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec[learn_start:]
ax2.plot(data, color = 'g')
ax2.plot(np.ones_like(data)*1500, 'g--')
ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_title('Time Steps',color = 'g')
for xpt in [250,500]:
    ax2.axvline(x=xpt,color='k',linewidth='0.8')
# ax2.set_yscale('log')
ax2.set_ylim([1,2.5e2])
fig.tight_layout()
ax2.grid()
plt.show()

# %%
torch.save(dqn.eval_net.state_dict(), 'cartpole_limited.pt')

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()

# %%
print("TOTAL TIMESTEPS: ", total_time_steps)
# Out:
# TOTAL TIMESTEPS:  199095
