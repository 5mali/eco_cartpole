# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE          = 32
LR                  = 1e-3  # learning rate
EPSILON             = 0.9   # greedy policy
GAMMA               = 0.9   # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY     = 2000
SEGREGATION_BIAS    = 6     # no. of non-terminal memories in batch

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(seed);

# %%
N_ACTIONS   = env.action_space.n
N_STATES    = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter  = 0 # for target updating
        
        self.good_memory_counter = 0 # for storing non-terminal memories
        self.good_memory         = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.bad_memory_counter  = 0 # for storing terminal memories
        self.bad_memory          = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.optimizer           = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func           = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        if r > 0: #non-terminal rewards
            # replace the old memory with new memory
            index = self.good_memory_counter % int(MEMORY_CAPACITY/2)
            self.good_memory[index, :] = transition
            self.good_memory_counter += 1
        
        else: #terminal rewards
            # replace the old memory with new memory
            index = self.bad_memory_counter % int(MEMORY_CAPACITY/2)
            self.bad_memory[index, :] = transition
            self.bad_memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        good_sample_index = np.random.choice(int(MEMORY_CAPACITY/2), int(SEGREGATION_BIAS))
        bad_sample_index  = np.random.choice(int(MEMORY_CAPACITY/2), int(BATCH_SIZE-SEGREGATION_BIAS))

        b_good_memory = self.good_memory[good_sample_index, :]
        b_bad_memory  = self.bad_memory[bad_sample_index, :]
        b_memory      = np.vstack((b_good_memory,b_bad_memory))
        
        b_s  = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a  = torch.LongTensor( b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r  = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval   = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next   = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss     = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = int(MEMORY_CAPACITY/2) + 1000

# %%
print('\nCollecting experience...')
REMEMBER_LIMIT = 4000
TIMESTEP_LIMIT = 5000
total_time_steps = 0
ep_r_rec = []
time_rec = []
flag = True
learn_start = 0
upgrade_metric = 200
upgrade_flag = False
upgrade_counter = 0
for i_episode in range(NO_OF_EPISODES):
       
    s = env.reset()
    ep_r = 0
    time_steps = 0
    stop_remember = False
    while True:
#         env.render()
        time_steps += 1
        total_time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)
        
        if time_steps > REMEMBER_LIMIT:
            stop_remember = True
        
        if (stop_remember == False):
            dqn.store_transition(s, a, r, s_)
        
        if time_steps > TIMESTEP_LIMIT:
            done = True
        
        if done:
            r = -1
            if time_steps >= TIMESTEP_LIMIT:
                r = 1
            dqn.store_transition(s, a, r, s_)
        
        ep_r += r
        if dqn.good_memory_counter > MEMORY_CAPACITY/2 and dqn.bad_memory_counter > MEMORY_CAPACITY/2:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                learn_start = i_episode
                flag = False
        
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 1000:
                print('EPISODE: {:4d}  |  TIME_STEPS: {:5d}  |  EPSILON: {:3.2f} | TOTAL TIME_STEPS: {:10d} '.format(i_episode, time_steps, EPSILON, total_time_steps))
            
            break
        s = s_
    
    #if mean of episode lenght of last 10 episodes is greater than upgrade_metric
    if np.mean(time_rec[-10:]) > upgrade_metric:
        upgrade_counter += 1
    else:
        upgrade_counter = 0
        
    if upgrade_counter > 10:
        upgrade_counter = 0
        print("Upgrading @ EPISODE: ", i_episode)
        upgrade_metric *= 2
        EPSILON += 0.02
# Out:
# Collecting experience...
# Learning starts from EPISODE:  1000
# Upgrading @ EPISODE:  1189
# EPISODE: 1466  |  TIME_STEPS:  2276  |  EPSILON: 0.92 | TOTAL TIME_STEPS:     112612
# Upgrading @ EPISODE:  1466
# EPISODE: 1468  |  TIME_STEPS:  3479  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     116437
# EPISODE: 1469  |  TIME_STEPS:  2305  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     118742
# EPISODE: 1483  |  TIME_STEPS:  3078  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     127993
# EPISODE: 1485  |  TIME_STEPS:  3595  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     131967
# EPISODE: 1782  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     215905
# EPISODE: 1783  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     220906
# EPISODE: 1784  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     225907
# EPISODE: 1785  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     230908
# EPISODE: 1786  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     235909
# EPISODE: 1787  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     240910
# EPISODE: 1788  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     245911
# EPISODE: 1789  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     250912
# EPISODE: 1790  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     255913
# EPISODE: 1791  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     260914
# EPISODE: 1792  |  TIME_STEPS:  5001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     265915
# Upgrading @ EPISODE:  1792
# EPISODE: 1793  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     270916
# EPISODE: 1794  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     275917
# EPISODE: 1795  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     280918
# EPISODE: 1796  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     285919
# EPISODE: 1797  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     290920
# EPISODE: 1798  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     295921
# EPISODE: 1799  |  TIME_STEPS:  5001  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     300922
# EPISODE: 1802  |  TIME_STEPS:  1222  |  EPSILON: 0.96 | TOTAL TIME_STEPS:     303492
# Upgrading @ EPISODE:  1803
# EPISODE: 1806  |  TIME_STEPS:  1611  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     306275
# EPISODE: 1811  |  TIME_STEPS:  1297  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     308615
# EPISODE: 1836  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     323545
# EPISODE: 1837  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     328546
# EPISODE: 1838  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     333547
# EPISODE: 1839  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     338548
# EPISODE: 1840  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     343549
# EPISODE: 1841  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     348550
# EPISODE: 1842  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     353551
# EPISODE: 1843  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     358552
# EPISODE: 1844  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     363553
# EPISODE: 1845  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     368554
# EPISODE: 1846  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     373555
# EPISODE: 1847  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     378556
# EPISODE: 1848  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     383557
# EPISODE: 1849  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     388558
# EPISODE: 1850  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     393559
# EPISODE: 1851  |  TIME_STEPS:  5001  |  EPSILON: 0.98 | TOTAL TIME_STEPS:     398560
# Upgrading @ EPISODE:  1851
# EPISODE: 1852  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     403561
# EPISODE: 1854  |  TIME_STEPS:  2240  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     406095
# EPISODE: 1855  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     411096
# EPISODE: 1858  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     416675
# EPISODE: 1861  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     422391
# EPISODE: 1862  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     427392
# EPISODE: 1863  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     432393
# EPISODE: 1864  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     437394
# EPISODE: 1865  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     442395
# EPISODE: 1866  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     447396
# EPISODE: 1867  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     452397
# EPISODE: 1868  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     457398
# EPISODE: 1869  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     462399
# EPISODE: 1870  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     467400
# EPISODE: 1871  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     472401
# EPISODE: 1872  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     477402
# EPISODE: 1873  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     482403
# EPISODE: 1874  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     487404
# EPISODE: 1875  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     492405
# EPISODE: 1876  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     497406
# EPISODE: 1877  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     502407
# EPISODE: 1878  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     507408
# EPISODE: 1879  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     512409
# EPISODE: 1880  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     517410
# EPISODE: 1881  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     522411
# EPISODE: 1882  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     527412
# EPISODE: 1883  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     532413
# EPISODE: 1884  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     537414
# EPISODE: 1885  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     542415
# EPISODE: 1886  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     547416
# EPISODE: 1887  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     552417
# EPISODE: 1888  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     557418
# EPISODE: 1889  |  TIME_STEPS:  4218  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     561636
# EPISODE: 1890  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     566637
# EPISODE: 1891  |  TIME_STEPS:  4262  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     570899
# EPISODE: 1892  |  TIME_STEPS:  2016  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     572915
# EPISODE: 1893  |  TIME_STEPS:  1255  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     574170
# EPISODE: 1936  |  TIME_STEPS:  2781  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     595630
# EPISODE: 1941  |  TIME_STEPS:  1118  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     599241
# EPISODE: 1943  |  TIME_STEPS:  1575  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     601265
# EPISODE: 1944  |  TIME_STEPS:  2553  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     603818
# EPISODE: 1946  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     609165
# EPISODE: 1948  |  TIME_STEPS:  5001  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     614880
# EPISODE: 1949  |  TIME_STEPS:  1268  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     616148
# EPISODE: 1950  |  TIME_STEPS:  1286  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     617434
# EPISODE: 1952  |  TIME_STEPS:  2534  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     620388
# EPISODE: 1954  |  TIME_STEPS:  2858  |  EPSILON: 1.00 | TOTAL TIME_STEPS:     623786

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec[learn_start:]
ax2.plot(data, color = 'g')
ax2.plot(np.ones_like(data)*1500, 'g--')
ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_title('Time Steps',color = 'g')
for xpt in [250,500]:
    ax2.axvline(x=xpt,color='k',linewidth='0.8')
ax2.set_yscale('log')
ax2.set_ylim([1,1e6])
fig.tight_layout()
ax2.grid()
plt.show()

# %%
torch.save(dqn.eval_net.state_dict(), 'cartpole_limit_5k.pt')

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()

# %%
print("TOTAL TIMESTEPS: ", total_time_steps)
# Out:
# TOTAL TIMESTEPS:  634995
