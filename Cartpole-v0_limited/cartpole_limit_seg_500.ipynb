# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE          = 32
LR                  = 1e-3  # learning rate
EPSILON             = 0.9   # greedy policy
GAMMA               = 0.9   # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY     = 2000
SEGREGATION_BIAS    = 6     # no. of non-terminal memories in batch

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(seed);

# %%
N_ACTIONS   = env.action_space.n
N_STATES    = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter  = 0 # for target updating
        
        self.good_memory_counter = 0 # for storing non-terminal memories
        self.good_memory         = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.bad_memory_counter  = 0 # for storing terminal memories
        self.bad_memory          = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.optimizer           = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func           = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        if r > 0: #non-terminal rewards
            # replace the old memory with new memory
            index = self.good_memory_counter % int(MEMORY_CAPACITY/2)
            self.good_memory[index, :] = transition
            self.good_memory_counter += 1
        
        else: #terminal rewards
            # replace the old memory with new memory
            index = self.bad_memory_counter % int(MEMORY_CAPACITY/2)
            self.bad_memory[index, :] = transition
            self.bad_memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        good_sample_index = np.random.choice(int(MEMORY_CAPACITY/2), int(SEGREGATION_BIAS))
        bad_sample_index  = np.random.choice(int(MEMORY_CAPACITY/2), int(BATCH_SIZE-SEGREGATION_BIAS))

        b_good_memory = self.good_memory[good_sample_index, :]
        b_bad_memory  = self.bad_memory[bad_sample_index, :]
        b_memory      = np.vstack((b_good_memory,b_bad_memory))
        
        b_s  = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a  = torch.LongTensor( b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r  = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval   = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next   = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss     = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = int(MEMORY_CAPACITY/2) + 1000

# %%
print('\nCollecting experience...')
REMEMBER_LIMIT = 4000
TIMESTEP_LIMIT = 500
total_time_steps = 0
ep_r_rec = []
time_rec = []
flag = True
learn_start = 0
upgrade_metric = 200
upgrade_flag = False
upgrade_counter = 0
for i_episode in range(NO_OF_EPISODES):
       
    s = env.reset()
    ep_r = 0
    time_steps = 0
    stop_remember = False
    while True:
#         env.render()
        time_steps += 1
        total_time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)
        
        if time_steps > REMEMBER_LIMIT:
            stop_remember = True
        
        if (stop_remember == False):
            dqn.store_transition(s, a, r, s_)
        
        if time_steps > TIMESTEP_LIMIT:
            done = True
        
        if done:
            r = -1
            if time_steps >= TIMESTEP_LIMIT:
                r = 1
            dqn.store_transition(s, a, r, s_)
        
        ep_r += r
        if dqn.good_memory_counter > MEMORY_CAPACITY/2 and dqn.bad_memory_counter > MEMORY_CAPACITY/2:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                learn_start = i_episode
                flag = False
        
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 450:
                print('EPISODE: {:4d}  |  TIME_STEPS: {:5d}  |  EPSILON: {:3.2f} | TOTAL TIME_STEPS: {:10d} '.format(i_episode, time_steps, EPSILON, total_time_steps))
            
            break
        s = s_
    
    #if mean of episode lenght of last 10 episodes is greater than upgrade_metric
    if np.mean(time_rec[-10:]) > upgrade_metric:
        upgrade_counter += 1
    else:
        upgrade_counter = 0
        
    if upgrade_counter > 10:
        upgrade_counter = 0
        print("Upgrading @ EPISODE: ", i_episode)
        upgrade_metric *= 2
        EPSILON += 0.02
# Out:
# Collecting experience...
# Learning starts from EPISODE:  1000
# Upgrading @ EPISODE:  1189
# EPISODE: 1195  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      38384
# EPISODE: 1206  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      41868
# EPISODE: 1211  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      43658
# EPISODE: 1219  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      46324
# EPISODE: 1222  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      47540
# EPISODE: 1223  |  TIME_STEPS:   492  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      48032
# EPISODE: 1224  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      48533
# EPISODE: 1230  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      50700
# EPISODE: 1232  |  TIME_STEPS:   473  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      51533
# EPISODE: 1243  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      54922
# EPISODE: 1248  |  TIME_STEPS:   464  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      56442
# EPISODE: 1288  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      68684
# EPISODE: 1290  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      69631
# EPISODE: 1293  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:      70977
# EPISODE: 1616  |  TIME_STEPS:   469  |  EPSILON: 0.92 | TOTAL TIME_STEPS:     153116
# EPISODE: 1618  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:     154026
# EPISODE: 1620  |  TIME_STEPS:   501  |  EPSILON: 0.92 | TOTAL TIME_STEPS:     154917
# Upgrading @ EPISODE:  1628
# EPISODE: 1629  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     158566
# EPISODE: 1630  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     159067
# EPISODE: 1631  |  TIME_STEPS:   480  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     159547
# EPISODE: 1633  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     160473
# EPISODE: 1634  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     160974
# EPISODE: 1635  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     161475
# EPISODE: 1636  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     161976
# EPISODE: 1638  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     162898
# EPISODE: 1640  |  TIME_STEPS:   476  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     163794
# EPISODE: 1641  |  TIME_STEPS:   497  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     164291
# EPISODE: 1642  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     164792
# EPISODE: 1644  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     165678
# EPISODE: 1645  |  TIME_STEPS:   472  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     166150
# EPISODE: 1646  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     166651
# EPISODE: 1647  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     167152
# EPISODE: 1650  |  TIME_STEPS:   475  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     168420
# EPISODE: 1651  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     168921
# EPISODE: 1652  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     169422
# EPISODE: 1653  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     169923
# EPISODE: 1657  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     171674
# EPISODE: 1659  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     172625
# EPISODE: 1660  |  TIME_STEPS:   493  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     173118
# EPISODE: 1661  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     173619
# EPISODE: 1662  |  TIME_STEPS:   491  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     174110
# EPISODE: 1663  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     174611
# EPISODE: 1665  |  TIME_STEPS:   458  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     175416
# EPISODE: 1666  |  TIME_STEPS:   496  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     175912
# EPISODE: 1668  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     176862
# EPISODE: 1669  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     177363
# EPISODE: 1670  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     177864
# EPISODE: 1671  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     178365
# EPISODE: 1672  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     178866
# EPISODE: 1673  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     179367
# EPISODE: 1674  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     179868
# EPISODE: 1675  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     180369
# EPISODE: 1676  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     180870
# EPISODE: 1677  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     181371
# EPISODE: 1678  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     181872
# EPISODE: 1679  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     182373
# EPISODE: 1680  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     182874
# EPISODE: 1681  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     183375
# EPISODE: 1682  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     183876
# EPISODE: 1683  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     184377
# EPISODE: 1684  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     184878
# EPISODE: 1685  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     185379
# EPISODE: 1686  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     185880
# EPISODE: 1687  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     186381
# EPISODE: 1688  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     186882
# EPISODE: 1689  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     187383
# EPISODE: 1690  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     187884
# EPISODE: 1691  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     188385
# EPISODE: 1692  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     188886
# EPISODE: 1693  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     189387
# EPISODE: 1695  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     190311
# EPISODE: 1696  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     190812
# EPISODE: 1698  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     191643
# EPISODE: 1699  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     192144
# EPISODE: 1700  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     192645
# EPISODE: 1702  |  TIME_STEPS:   493  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     193550
# EPISODE: 1703  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     194051
# EPISODE: 1704  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     194552
# EPISODE: 1706  |  TIME_STEPS:   492  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     195445
# EPISODE: 1707  |  TIME_STEPS:   460  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     195905
# EPISODE: 1708  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     196406
# EPISODE: 1709  |  TIME_STEPS:   490  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     196896
# EPISODE: 1710  |  TIME_STEPS:   489  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     197385
# EPISODE: 1711  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     197886
# EPISODE: 1713  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     198738
# EPISODE: 1714  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     199239
# EPISODE: 1715  |  TIME_STEPS:   498  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     199737
# EPISODE: 1716  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     200238
# EPISODE: 1717  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     200739
# EPISODE: 1718  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     201240
# EPISODE: 1719  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     201741
# EPISODE: 1720  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     202242
# EPISODE: 1721  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     202743
# EPISODE: 1722  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     203244
# EPISODE: 1723  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     203745
# EPISODE: 1724  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     204246
# EPISODE: 1725  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     204747
# EPISODE: 1726  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     205248
# EPISODE: 1727  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     205749
# EPISODE: 1728  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     206250
# EPISODE: 1729  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     206751
# EPISODE: 1730  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     207252
# EPISODE: 1731  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     207753
# EPISODE: 1732  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     208254
# EPISODE: 1733  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     208755
# EPISODE: 1734  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     209256
# EPISODE: 1735  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     209757
# EPISODE: 1736  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     210258
# EPISODE: 1737  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     210759
# EPISODE: 1738  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     211260
# EPISODE: 1739  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     211761
# EPISODE: 1740  |  TIME_STEPS:   487  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     212248
# EPISODE: 1741  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     212749
# EPISODE: 1742  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     213250
# EPISODE: 1743  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     213751
# EPISODE: 1744  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     214252
# EPISODE: 1745  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     214753
# EPISODE: 1746  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     215254
# EPISODE: 1747  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     215755
# EPISODE: 1748  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     216256
# EPISODE: 1749  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     216757
# EPISODE: 1750  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     217258
# EPISODE: 1752  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     218201
# EPISODE: 1753  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     218702
# EPISODE: 1754  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     219203
# EPISODE: 1755  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     219704
# EPISODE: 1756  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     220205
# EPISODE: 1757  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     220706
# EPISODE: 1758  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     221207
# EPISODE: 1759  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     221708
# EPISODE: 1761  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     222602
# EPISODE: 1762  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     223103
# EPISODE: 1763  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     223604
# EPISODE: 1764  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     224105
# EPISODE: 1765  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     224606
# EPISODE: 1766  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     225107
# EPISODE: 1767  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     225608
# EPISODE: 1768  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     226109
# EPISODE: 1769  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     226610
# EPISODE: 1770  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     227111
# EPISODE: 1771  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     227612
# EPISODE: 1772  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     228113
# EPISODE: 1773  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     228614
# EPISODE: 1774  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     229115
# EPISODE: 1775  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     229616
# EPISODE: 1776  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     230117
# EPISODE: 1777  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     230618
# EPISODE: 1778  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     231119
# EPISODE: 1779  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     231620
# EPISODE: 1780  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     232121
# EPISODE: 1781  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     232622
# EPISODE: 1782  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     233123
# EPISODE: 1783  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     233624
# EPISODE: 1784  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     234125
# EPISODE: 1785  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     234626
# EPISODE: 1786  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     235127
# EPISODE: 1787  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     235628
# EPISODE: 1788  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     236129
# EPISODE: 1789  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     236630
# EPISODE: 1790  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     237131
# EPISODE: 1791  |  TIME_STEPS:   495  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     237626
# EPISODE: 1793  |  TIME_STEPS:   464  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     238477
# EPISODE: 1794  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     238978
# EPISODE: 1795  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     239479
# EPISODE: 1796  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     239980
# EPISODE: 1797  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     240481
# EPISODE: 1800  |  TIME_STEPS:   453  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     241712
# EPISODE: 1801  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     242213
# EPISODE: 1802  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     242714
# EPISODE: 1803  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     243215
# EPISODE: 1804  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     243716
# EPISODE: 1805  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     244217
# EPISODE: 1806  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     244718
# EPISODE: 1807  |  TIME_STEPS:   453  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     245171
# EPISODE: 1808  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     245672
# EPISODE: 1809  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     246173
# EPISODE: 1810  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     246674
# EPISODE: 1811  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     247175
# EPISODE: 1812  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     247676
# EPISODE: 1813  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     248177
# EPISODE: 1814  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     248678
# EPISODE: 1815  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     249179
# EPISODE: 1816  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     249680
# EPISODE: 1817  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     250181
# EPISODE: 1819  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     251131
# EPISODE: 1842  |  TIME_STEPS:   477  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     258874
# EPISODE: 1845  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     260137
# EPISODE: 1846  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     260638
# EPISODE: 1847  |  TIME_STEPS:   459  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     261097
# EPISODE: 1848  |  TIME_STEPS:   486  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     261583
# EPISODE: 1851  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     262845
# EPISODE: 1852  |  TIME_STEPS:   471  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     263316
# EPISODE: 1855  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     264588
# EPISODE: 1860  |  TIME_STEPS:   451  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     266624
# EPISODE: 1862  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     267564
# EPISODE: 1871  |  TIME_STEPS:   491  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     271249
# EPISODE: 1873  |  TIME_STEPS:   464  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     272078
# EPISODE: 1875  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     273000
# EPISODE: 1876  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     273501
# EPISODE: 1889  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     278567
# EPISODE: 1890  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     279068
# EPISODE: 1891  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     279569
# EPISODE: 1892  |  TIME_STEPS:   454  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     280023
# EPISODE: 1893  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     280524
# EPISODE: 1894  |  TIME_STEPS:   470  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     280994
# EPISODE: 1895  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     281495
# EPISODE: 1896  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     281996
# EPISODE: 1897  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     282497
# EPISODE: 1898  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     282998
# EPISODE: 1899  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     283499
# EPISODE: 1900  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     284000
# EPISODE: 1901  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     284501
# EPISODE: 1902  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     285002
# EPISODE: 1903  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     285503
# EPISODE: 1904  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     286004
# EPISODE: 1905  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     286505
# EPISODE: 1906  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     287006
# EPISODE: 1907  |  TIME_STEPS:   475  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     287481
# EPISODE: 1908  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     287982
# EPISODE: 1909  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     288483
# EPISODE: 1910  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     288984
# EPISODE: 1911  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     289485
# EPISODE: 1912  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     289986
# EPISODE: 1913  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     290487
# EPISODE: 1914  |  TIME_STEPS:   495  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     290982
# EPISODE: 1915  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     291483
# EPISODE: 1916  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     291984
# EPISODE: 1917  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     292485
# EPISODE: 1918  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     292986
# EPISODE: 1919  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     293487
# EPISODE: 1920  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     293988
# EPISODE: 1921  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     294489
# EPISODE: 1922  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     294990
# EPISODE: 1923  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     295491
# EPISODE: 1924  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     295992
# EPISODE: 1925  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     296493
# EPISODE: 1926  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     296994
# EPISODE: 1927  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     297495
# EPISODE: 1928  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     297996
# EPISODE: 1929  |  TIME_STEPS:   495  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     298491
# EPISODE: 1930  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     298992
# EPISODE: 1931  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     299493
# EPISODE: 1932  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     299994
# EPISODE: 1933  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     300495
# EPISODE: 1934  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     300996
# EPISODE: 1936  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     301906
# EPISODE: 1940  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     303622
# EPISODE: 1942  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     304512
# EPISODE: 1943  |  TIME_STEPS:   462  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     304974
# EPISODE: 1944  |  TIME_STEPS:   491  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     305465
# EPISODE: 1954  |  TIME_STEPS:   487  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     309577
# EPISODE: 1955  |  TIME_STEPS:   476  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     310053
# EPISODE: 1956  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     310554
# EPISODE: 1957  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     311055
# EPISODE: 1958  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     311556
# EPISODE: 1959  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     312057
# EPISODE: 1960  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     312558
# EPISODE: 1961  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     313059
# EPISODE: 1962  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     313560
# EPISODE: 1963  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     314061
# EPISODE: 1964  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     314562
# EPISODE: 1965  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     315063
# EPISODE: 1966  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     315564
# EPISODE: 1967  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     316065
# EPISODE: 1968  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     316566
# EPISODE: 1969  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     317067
# EPISODE: 1970  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     317568
# EPISODE: 1971  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     318069
# EPISODE: 1972  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     318570
# EPISODE: 1973  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     319071
# EPISODE: 1974  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     319572
# EPISODE: 1975  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     320073
# EPISODE: 1976  |  TIME_STEPS:   483  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     320556
# EPISODE: 1977  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     321057
# EPISODE: 1987  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     324937
# EPISODE: 1988  |  TIME_STEPS:   469  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     325406
# EPISODE: 1989  |  TIME_STEPS:   484  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     325890
# EPISODE: 1990  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     326391
# EPISODE: 1991  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     326892
# EPISODE: 1992  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     327393
# EPISODE: 1993  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     327894
# EPISODE: 1994  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     328395
# EPISODE: 1995  |  TIME_STEPS:   501  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     328896
# EPISODE: 1996  |  TIME_STEPS:   456  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     329352
# EPISODE: 1997  |  TIME_STEPS:   472  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     329824
# EPISODE: 1998  |  TIME_STEPS:   473  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     330297

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec[learn_start:]
ax2.plot(data, color = 'g')
ax2.plot(np.ones_like(data)*1500, 'g--')
ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_title('Time Steps',color = 'g')
for xpt in [250,500]:
    ax2.axvline(x=xpt,color='k',linewidth='0.8')
ax2.set_yscale('log')
ax2.set_ylim([1,1e6])
fig.tight_layout()
ax2.grid()
plt.show()

# %%
torch.save(dqn.eval_net.state_dict(), 'cartpole_limit_500.pt')

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()

# %%
print("TOTAL TIMESTEPS: ", total_time_steps)
# Out:
# TOTAL TIMESTEPS:  330747
