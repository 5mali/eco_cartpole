# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE          = 32
LR                  = 1e-3  # learning rate
EPSILON             = 0.9   # greedy policy
GAMMA               = 0.9   # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY     = 2000
SEGREGATION_BIAS    = 6     # no. of non-terminal memories in batch

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(seed);

# %%
N_ACTIONS   = env.action_space.n
N_STATES    = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter  = 0 # for target updating
        
        self.good_memory_counter = 0 # for storing non-terminal memories
        self.good_memory         = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.bad_memory_counter  = 0 # for storing terminal memories
        self.bad_memory          = np.zeros((int(MEMORY_CAPACITY/2), N_STATES * 2 + 2)) # initialize memory
        
        self.optimizer           = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func           = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        if r > 0: #non-terminal rewards
            # replace the old memory with new memory
            index = self.good_memory_counter % int(MEMORY_CAPACITY/2)
            self.good_memory[index, :] = transition
            self.good_memory_counter += 1
        
        else: #terminal rewards
            # replace the old memory with new memory
            index = self.bad_memory_counter % int(MEMORY_CAPACITY/2)
            self.bad_memory[index, :] = transition
            self.bad_memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        good_sample_index = np.random.choice(int(MEMORY_CAPACITY/2), int(SEGREGATION_BIAS))
        bad_sample_index  = np.random.choice(int(MEMORY_CAPACITY/2), int(BATCH_SIZE-SEGREGATION_BIAS))

        b_good_memory = self.good_memory[good_sample_index, :]
        b_bad_memory  = self.bad_memory[bad_sample_index, :]
        b_memory      = np.vstack((b_good_memory,b_bad_memory))
        
        b_s  = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a  = torch.LongTensor( b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r  = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval   = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next   = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss     = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = int(MEMORY_CAPACITY/2) + 1000

# %%
print('\nCollecting experience...')
REMEMBER_LIMIT = 4000
TIMESTEP_LIMIT = 10000
total_time_steps = 0
ep_r_rec = []
time_rec = []
flag = True
learn_start = 0
upgrade_metric = 200
upgrade_flag = False
upgrade_counter = 0
for i_episode in range(NO_OF_EPISODES):
       
    s = env.reset()
    ep_r = 0
    time_steps = 0
    stop_remember = False
    while True:
#         env.render()
        time_steps += 1
        total_time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)
        
        if time_steps > REMEMBER_LIMIT:
            stop_remember = True
        
        if (stop_remember == False):
            dqn.store_transition(s, a, r, s_)
        
        if time_steps > TIMESTEP_LIMIT:
            done = True
        
        if done:
            r = -1
            if time_steps >= TIMESTEP_LIMIT:
                r = 1
            dqn.store_transition(s, a, r, s_)
        
        ep_r += r
        if dqn.good_memory_counter > MEMORY_CAPACITY/2 and dqn.bad_memory_counter > MEMORY_CAPACITY/2:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                learn_start = i_episode
                flag = False
        
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 1000:
                print('EPISODE: {:4d}  |  TIME_STEPS: {:5d}  |  EPSILON: {:3.2f} | TOTAL TIME_STEPS: {:10d} '.format(i_episode, time_steps, EPSILON, total_time_steps))
            
            break
        s = s_
    
    #if mean of episode lenght of last 10 episodes is greater than upgrade_metric
    if np.mean(time_rec[-10:]) > upgrade_metric:
        upgrade_counter += 1
    else:
        upgrade_counter = 0
        
    if upgrade_counter > 10:
        upgrade_counter = 0
        print("Upgrading @ EPISODE: ", i_episode)
        upgrade_metric *= 2
        EPSILON += 0.02
# Out:
# Collecting experience...
# Learning starts from EPISODE:  1000
# Upgrading @ EPISODE:  1189
# EPISODE: 1466  |  TIME_STEPS:  2276  |  EPSILON: 0.92 | TOTAL TIME_STEPS:     112612
# Upgrading @ EPISODE:  1466
# EPISODE: 1468  |  TIME_STEPS:  3479  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     116437
# EPISODE: 1469  |  TIME_STEPS:  2305  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     118742
# EPISODE: 1483  |  TIME_STEPS:  3078  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     127993
# EPISODE: 1485  |  TIME_STEPS:  3595  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     131967
# EPISODE: 1782  |  TIME_STEPS: 10001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     220905
# EPISODE: 1783  |  TIME_STEPS: 10001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     230906
# EPISODE: 1784  |  TIME_STEPS: 10001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     240907
# EPISODE: 1785  |  TIME_STEPS: 10001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:     250908
# EPISODE: 1786  |  TIME_STEPS: 10001  |  EPSILON: 0.94 | TOTAL TIME_STEPS:
|  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1003381
# EPISODE: 1931  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1013382
# EPISODE: 1932  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1023383
# EPISODE: 1933  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1033384
# EPISODE: 1934  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1043385
# EPISODE: 1935  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1053386
# EPISODE: 1936  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1063387
# EPISODE: 1937  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1073388
# EPISODE: 1938  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1083389
# EPISODE: 1939  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1093390
# EPISODE: 1940  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1103391
# EPISODE: 1941  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1113392
# EPISODE: 1942  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1123393
# EPISODE: 1943  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1133394
# EPISODE: 1944  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1143395
# EPISODE: 1945  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1153396
# EPISODE: 1946  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1163397
# EPISODE: 1947  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1173398
# EPISODE: 1948  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1183399
# EPISODE: 1949  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1193400
# EPISODE: 1950  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1203401
# EPISODE: 1951  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1213402
# EPISODE: 1952  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1223403
# EPISODE: 1953  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1233404
# EPISODE: 1954  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1243405
# EPISODE: 1955  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1253406
# EPISODE: 1956  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1263407
# EPISODE: 1957  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1273408
# EPISODE: 1958  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1283409
# EPISODE: 1959  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1293410
# EPISODE: 1960  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1303411
# EPISODE: 1961  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1313412
# EPISODE: 1962  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1323413
# EPISODE: 1963  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1333414
# EPISODE: 1964  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1343415
# EPISODE: 1965  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1353416
# EPISODE: 1966  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1363417
# EPISODE: 1967  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1373418
# EPISODE: 1968  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1383419
# EPISODE: 1969  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1393420
# EPISODE: 1970  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1403421
# EPISODE: 1971  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1413422
# EPISODE: 1972  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1423423
# EPISODE: 1973  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1433424
# EPISODE: 1974  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1443425
# EPISODE: 1975  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1453426
# EPISODE: 1976  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1463427
# EPISODE: 1977  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1473428
# EPISODE: 1978  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1483429
# EPISODE: 1979  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1493430
# EPISODE: 1980  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1503431
# EPISODE: 1981  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1513432
# EPISODE: 1982  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1523433
# EPISODE: 1983  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1533434
# EPISODE: 1984  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1543435
# EPISODE: 1985  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1553436
# EPISODE: 1986  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1563437
# EPISODE: 1987  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1573438
# EPISODE: 1988  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1583439
# EPISODE: 1989  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1593440
# EPISODE: 1990  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1603441
# EPISODE: 1991  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1613442
# EPISODE: 1992  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1623443
# EPISODE: 1993  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1633444
# EPISODE: 1994  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1643445
# EPISODE: 1995  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1653446
# EPISODE: 1996  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1663447
# EPISODE: 1997  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1673448
# EPISODE: 1998  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1683449
# EPISODE: 1999  |  TIME_STEPS: 10001  |  EPSILON: 1.02 | TOTAL TIME_STEPS:    1693450

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec[learn_start:]
ax2.plot(data, color = 'g')
ax2.plot(np.ones_like(data)*1500, 'g--')
ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_title('Time Steps',color = 'g')
for xpt in [250,500]:
    ax2.axvline(x=xpt,color='k',linewidth='0.8')
ax2.set_yscale('log')
ax2.set_ylim([1,1e6])
fig.tight_layout()
ax2.grid()
plt.show()

# %%
torch.save(dqn.eval_net.state_dict(), 'cartpole_limit_10k.pt')

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()

# %%
print("TOTAL TIMESTEPS: ", total_time_steps)
# Out:
# TOTAL TIMESTEPS:  1693450
