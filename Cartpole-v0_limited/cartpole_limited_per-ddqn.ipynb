# %%
# %matplotlib inline
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# SumTree
# a binary tree data structure where the parent’s value is the sum of its children
class SumTree:
    write = 0

    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1)
        self.data = np.zeros(capacity, dtype=object)
        self.n_entries = 0

    # update to the root node
    def _propagate(self, idx, change):
        parent = (idx - 1) // 2

        self.tree[parent] += change

        if parent != 0:
            self._propagate(parent, change)

    # find sample on leaf node
    def _retrieve(self, idx, s):
        left = 2 * idx + 1
        right = left + 1

        if left >= len(self.tree):
            return idx

        if s <= self.tree[left]:
            return self._retrieve(left, s)
        else:
            return self._retrieve(right, s - self.tree[left])

    def total(self):
        return self.tree[0]

    # store priority and sample
    def add(self, p, data):
        idx = self.write + self.capacity - 1

        self.data[self.write] = data
        self.update(idx, p)

        self.write += 1
        if self.write >= self.capacity:
            self.write = 0

        if self.n_entries < self.capacity:
            self.n_entries += 1

    # update priority
    def update(self, idx, p):
        change = p - self.tree[idx]

        self.tree[idx] = p
        self._propagate(idx, change)

    # get priority and sample
    def get(self, s):
        idx = self._retrieve(0, s)
        dataIdx = idx - self.capacity + 1

        return (idx, self.tree[idx], self.data[dataIdx])

# %%
class Memory:  # stored as ( s, a, r, s_ ) in SumTree
    e = 0.01
    a = 0.6
    beta = 0.4
    beta_increment_per_sampling = 0.001

    def __init__(self, capacity):
        self.tree = SumTree(capacity)
        self.capacity = capacity

    def _get_priority(self, error):
        return (error + self.e) ** self.a

    def add(self, error, sample):
        p = self._get_priority(error)
        self.tree.add(p, sample)

    def sample(self, n):
        batch = []
        idxs = []
        segment = self.tree.total() / n
        priorities = []

        self.beta = np.min([1., self.beta + self.beta_increment_per_sampling])

        for i in range(n):
            a = segment * i
            b = segment * (i + 1)

            s = random.uniform(a, b)
            (idx, p, data) = self.tree.get(s)
            priorities.append(p)
            batch.append(data)
            idxs.append(idx)

        sampling_probabilities = priorities / self.tree.total()
        is_weight = np.power(self.tree.n_entries * sampling_probabilities, -self.beta)
        is_weight /= is_weight.max()

        return batch, idxs, is_weight

    def update(self, idx, error):
        p = self._get_priority(error)
        self.tree.update(idx, p)

# %%
# Hyper Parameters
BATCH_SIZE = 32
LR = 1e-2                  # learning rate
EPSILON = 0.9               # greedy policy
GAMMA = 0.9                 # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY = 2000

# %%
env = gym.make('CartPole-v0')
env.seed(seed);

# %%
N_ACTIONS = env.action_space.n
N_STATES = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter = 0                                     # for target updating
        self.memory_counter = 0                                         # for storing memory
        self.pmemory = Memory(MEMORY_CAPACITY)
        self.memory = np.zeros((MEMORY_CAPACITY, N_STATES * 2 + 2))     # initialize memory
        self.optimizer = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func = nn.MSELoss(reduce=False)

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

#     def store_transition(self, s, a, r, s_):
#         transition = np.hstack((s, [a, r], s_))
#         # replace the old memory with new memory
#         index = self.memory_counter % MEMORY_CAPACITY
#         self.memory[index, :] = transition
#         self.memory_counter += 1

    def store_transition(self, s, a, r, s_, done):
        
        ns = torch.unsqueeze(torch.FloatTensor(s_), 0)
        ns_vals = self.eval_net.forward(ns).data
        
        ps = torch.unsqueeze(torch.FloatTensor(s), 0)
        ps_vals = self.eval_net.forward(ps).data
        expected_q = ps_vals[0][a]

        if done:
            actual_q = r
        else:
            actual_q = r + GAMMA * torch.max(ns_vals)
        
        error = np.abs(expected_q - actual_q)
        self.pmemory.add(error, (s, a, r, s_, done))


#         transition = np.hstack((s, [a, r], s_))
#         # replace the old memory with new memory
#         index = self.memory_counter % MEMORY_CAPACITY
#         self.memory[index, :] = transition
        self.memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        #sample from pmemory
        mini_batch, idxs, is_weights = self.pmemory.sample(BATCH_SIZE)
        mini_batch = np.array(mini_batch).transpose()
        
        states = np.vstack(mini_batch[0])
        actions = np.vstack(mini_batch[1])
        rewards = np.vstack(mini_batch[2])
        next_states = np.vstack(mini_batch[3])
        dones = mini_batch[4]
        my_memory = np.hstack((states,actions,rewards,next_states))
        
        
        # sample batch transitions
#         sample_index = np.random.choice(MEMORY_CAPACITY, BATCH_SIZE)
#         b_memory = self.memory[sample_index, :]
        
        b_memory = my_memory
        b_s = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a = torch.LongTensor(b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

         # q_eval w.r.t the action in experience
        q_eval   = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        a_eval   = self.eval_net(b_s).max(1)[1].view(BATCH_SIZE, 1) #best action according to eval_net
        q_next   = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.gather(1, a_eval)   # shape (batch, 1)
        
        errors = torch.abs(q_eval - q_target).data.numpy()
        # update priority
        for i in range(BATCH_SIZE):
            idx = idxs[i]
            self.pmemory.update(idx, errors[i])

        self.optimizer.zero_grad()
        
#         loss = self.loss_func(q_eval, q_target)
        loss = self.loss_func(q_eval, q_target)*torch.from_numpy(is_weights).float()
        
        self.optimizer.zero_grad()
        loss.mean().backward()
#         loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = 1000

# %%
print('\nCollecting experience...')
time_rec = []
flag = True
learn_start = 0
TIMESTEP_LIMIT = 200

for i_episode in range(NO_OF_EPISODES):
    s = env.reset()
    time_steps = 0
    while True:
#         env.render()
        time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)
        
        if done:
            r = -1
            if time_steps >= TIMESTEP_LIMIT:
                r = 1
            
        dqn.store_transition(s, a, r, s_, done)
        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                flag = False

        if done:
            print("EPISODE#{:4d} | TIME_STEPS: {:6d} | MEMORY_LENGTH: {:10d}".format(int(i_episode), int(time_steps), int(dqn.pmemory.tree.n_entries)))
            time_rec = np.append(time_rec, time_steps)
         
            break
        s = s_
# Out:
# Collecting experience...
# EPISODE#   0 | TIME_STEPS:     10 | MEMORY_LENGTH:         10
# EPISODE#   1 | TIME_STEPS:     10 | MEMORY_LENGTH:         20
# EPISODE#   2 | TIME_STEPS:      9 | MEMORY_LENGTH:         29
# EPISODE#   3 | TIME_STEPS:      8 | MEMORY_LENGTH:         37
# EPISODE#   4 | TIME_STEPS:     14 | MEMORY_LENGTH:         51
# EPISODE#   5 | TIME_STEPS:     10 | MEMORY_LENGTH:         61
# EPISODE#   6 | TIME_STEPS:     10 | MEMORY_LENGTH:         71
# EPISODE#   7 | TIME_STEPS:      9 | MEMORY_LENGTH:         80
# EPISODE#   8 | TIME_STEPS:     10 | MEMORY_LENGTH:         90
# EPISODE#   9 | TIME_STEPS:     13 | MEMORY_LENGTH:        103
# EPISODE#  10 | TIME_STEPS:     10 | MEMORY_LENGTH:        113
# EPISODE#  11 | TIME_STEPS:     11 | MEMORY_LENGTH:        124
# EPISODE#  12 | TIME_STEPS:      9 | MEMORY_LENGTH:        133
# EPISODE#  13 | TIME_STEPS:     10 | MEMORY_LENGTH:        143
# EPISODE#  14 | TIME_STEPS:     12 | MEMORY_LENGTH:        155
# EPISODE#  15 | TIME_STEPS:     10 | MEMORY_LENGTH:        165
# EPISODE#  16 | TIME_STEPS:      9 | MEMORY_LENGTH:        174
# EPISODE#  17 | TIME_STEPS:     11 | MEMORY_LENGTH:        185
# EPISODE#  18 | TIME_STEPS:     13 | MEMORY_LENGTH:        198
# EPISODE#  19 | TIME_STEPS:      9 | MEMORY_LENGTH:        207
# EPISODE#  20 | TIME_STEPS:      8 | MEMORY_LENGTH:        215
# EPISODE#  21 | TIME_STEPS:     10 | MEMORY_LENGTH:        225
# EPISODE#  22 | TIME_STEPS:     10 | MEMORY_LENGTH:        235
# EPISODE#  23 | TIME_STEPS:     10 | MEMORY_LENGTH:        245
# EPISODE#  24 | TIME_STEPS:      9 | MEMORY_LENGTH:        254
# EPISODE#  25 | TIME_STEPS:     11 | MEMORY_LENGTH:        265
# EPISODE#  26 | TIME_STEPS:     11 | MEMORY_LENGTH:        276
# EPISODE#  27 | TIME_STEPS:     10 | MEMORY_LENGTH:        286
# EPISODE#  28 | TIME_STEPS:     10 | MEMORY_LENGTH:        296
# EPISODE#  29 | TIME_STEPS:      9 | MEMORY_LENGTH:        305
# EPISODE#  30 | TIME_STEPS:     11 | MEMORY_LENGTH:        316
# EPISODE#  31 | TIME_STEPS:     10 | MEMORY_LENGTH:        326
# EPISODE#  32 | TIME_STEPS:     10 | MEMORY_LENGTH:        336
# EPISODE#  33 | TIME_STEPS:      9 | MEMORY_LENGTH:        345
# EPISODE#  34 | TIME_STEPS:     10 | MEMORY_LENGTH:        355
# EPISODE#  35 | TIME_STEPS:     14 | MEMORY_LENGTH:        369
# EPISODE#  36 | TIME_STEPS:     10 | MEMORY_LENGTH:        379
# EPISODE#  37 | TIME_STEPS:     10 | MEMORY_LENGTH:        389
# EPISODE#  38 | TIME_STEPS:     11 | MEMORY_LENGTH:        400
# EPISODE#  39 | TIME_STEPS:      9 | MEMORY_LENGTH:        409
# EPISODE#  40 | TIME_STEPS:      9 | MEMORY_LENGTH:        418
# EPISODE#  41 | TIME_STEPS:      8 | MEMORY_LENGTH:        426
# EPISODE#  42 | TIME_STEPS:     11 | MEMORY_LENGTH:        437
# EPISODE#  43 | TIME_STEPS:     10 | MEMORY_LENGTH:        447
# EPISODE#  44 | TIME_STEPS:     10 | MEMORY_LENGTH:        457
# EPISODE#  45 | TIME_STEPS:      9 | MEMORY_LENGTH:        466
# EPISODE#  46 | TIME_STEPS:     10 | MEMORY_LENGTH:        476
# EPISODE#  47 | TIME_STEPS:     10 | MEMORY_LENGTH:        486
# EPISODE#  48 | TIME_STEPS:     10 | MEMORY_LENGTH:        496
# EPISODE#  49 | TIME_STEPS:     10 | MEMORY_LENGTH:        506
# EPISODE#  50 | TIME_STEPS:      9 | MEMORY_LENGTH:        515
# EPISODE#  51 | TIME_STEPS:      9 | MEMORY_LENGTH:        524
# EPISODE#  52 | TIME_STEPS:     10 | MEMORY_LENGTH:        534
# EPISODE#  53 | TIME_STEPS:      9 | MEMORY_LENGTH:        543
# EPISODE#  54 | TIME_STEPS:     10 | MEMORY_LENGTH:        553
# EPISODE#  55 | TIME_STEPS:      9 | MEMORY_LENGTH:        562
# EPISODE#  56 | TIME_STEPS:      9 | MEMORY_LENGTH:        571
# EPISODE#  57 | TIME_STEPS:      9 | MEMORY_LENGTH:        580
# EPISODE#  58 | TIME_STEPS:      8 | MEMORY_LENGTH:        588
# EPISODE#  59 | TIME_STEPS:     11 | MEMORY_LENGTH:        599
# EPISODE#  60 | TIME_STEPS:      8 | MEMORY_LENGTH:        607
# EPISODE#  61 | TIME_STEPS:      9 | MEMORY_LENGTH:        616
# EPISODE#  62 | TIME_STEPS:      9 | MEMORY_LENGTH:        625
# EPISODE#  63 | TIME_STEPS:     23 | MEMORY_LENGTH:        648
# EPISODE#  64 | TIME_STEPS:     15 | MEMORY_LENGTH:        663
# EPISODE#  65 | TIME_STEPS:     10 | MEMORY_LENGTH:        673
# EPISODE#  66 | TIME_STEPS:      9 | MEMORY_LENGTH:        682
# EPISODE#  67 | TIME_STEPS:      9 | MEMORY_LENGTH:        691
# EPISODE#  68 | TIME_STEPS:      9 | MEMORY_LENGTH:        700
# EPISODE#  69 | TIME_STEPS:      9 | MEMORY_LENGTH:        709
# EPISODE#  70 | TIME_STEPS:      8 | MEMORY_LENGTH:        717
# EPISODE#  71 | TIME_STEPS:     10 | MEMORY_LENGTH:        727
# EPISODE#  72 | TIME_STEPS:     10 | MEMORY_LENGTH:        737
# EPISODE#  73 | TIME_STEPS:     11 | MEMORY_LENGTH:        748
# EPISODE#  74 | TIME_STEPS:     11 | MEMORY_LENGTH:        759
# EPISODE#  75 | TIME_STEPS:     10 | MEMORY_LENGTH:        769
# EPISODE#  76 | TIME_STEPS:     10 | MEMORY_LENGTH:        779
# EPISODE#  77 | TIME_STEPS:      9 | MEMORY_LENGTH:        788
# EPISODE#  78 | TIME_STEPS:     10 | MEMORY_LENGTH:        798
# EPISODE#  79 | TIME_STEPS:      9 | MEMORY_LENGTH:        807
# EPISODE#  80 | TIME_STEPS:      9 | MEMORY_LENGTH:        816
# EPISODE#  81 | TIME_STEPS:     11 | MEMORY_LENGTH:        827
# EPISODE#  82 | TIME_STEPS:     12 | MEMORY_LENGTH:        839
# EPISODE#  83 | TIME_STEPS:      9 | MEMORY_LENGTH:        848
# EPISODE#  84 | TIME_STEPS:      9 | MEMORY_LENGTH:        857
# EPISODE#  85 | TIME_STEPS:     10 | MEMORY_LENGTH:        867
# EPISODE#  86 | TIME_STEPS:     10 | MEMORY_LENGTH:        877
# EPISODE#  87 | TIME_STEPS:     11 | MEMORY_LENGTH:        888
# EPISODE#  88 | TIME_STEPS:     11 | MEMORY_LENGTH:        899
# EPISODE#  89 | TIME_STEPS:     10 | MEMORY_LENGTH:        909
# EPISODE#  90 | TIME_STEPS:     10 | MEMORY_LENGTH:        919
# EPISODE#  91 | TIME_STEPS:      9 | MEMORY_LENGTH:        928
# EPISODE#  92 | TIME_STEPS:      9 | MEMORY_LENGTH:        937
# EPISODE#  93 | TIME_STEPS:      9 | MEMORY_LENGTH:        946
# EPISODE#  94 | TIME_STEPS:     10 | MEMORY_LENGTH:        956
# EPISODE#  95 | TIME_STEPS:     11 | MEMORY_LENGTH:        967
# EPISODE#  96 | TIME_STEPS:      9 | MEMORY_LENGTH:        976
# EPISODE#  97 | TIME_STEPS:     10 | MEMORY_LENGTH:        986
# EPISODE#  98 | TIME_STEPS:     11 | MEMORY_LENGTH:        997
# EPISODE#  99 | TIME_STEPS:     10 | MEMORY_LENGTH:       1007
# EPISODE# 100 | TIME_STEPS:      8 | MEMORY_LENGTH:       1015
# EPISODE# 101 | TIME_STEPS:     11 | MEMORY_LENGTH:       1026
# EPISODE# 102 | TIME_STEPS:     10 | MEMORY_LENGTH:       1036
# EPISODE# 103 | TIME_STEPS:     12 | MEMORY_LENGTH:       1048
# EPISODE# 104 | TIME_STEPS:     10 | MEMORY_LENGTH:       1058
# EPISODE# 105 | TIME_STEPS:     11 | MEMORY_LENGTH:       1069
# EPISODE# 106 | TIME_STEPS:     10 | MEMORY_LENGTH:       1079
# EPISODE# 107 | TIME_STEPS:     10 | MEMORY_LENGTH:       1089
# EPISODE# 108 | TIME_STEPS:      9 | MEMORY_LENGTH:       1098
# EPISODE# 109 | TIME_STEPS:     10 | MEMORY_LENGTH:       1108
# EPISODE# 110 | TIME_STEPS:      9 | MEMORY_LENGTH:       1117
# EPISODE# 111 | TIME_STEPS:     12 | MEMORY_LENGTH:       1129
# EPISODE# 112 | TIME_STEPS:     10 | MEMORY_LENGTH:       1139
# EPISODE# 113 | TIME_STEPS:     12 | MEMORY_LENGTH:       1151
# EPISODE# 114 | TIME_STEPS:     10 | MEMORY_LENGTH:       1161
# EPISODE# 115 | TIME_STEPS:      8 | MEMORY_LENGTH:       1169
# EPISODE# 116 | TIME_STEPS:     10 | MEMORY_LENGTH:       1179
# EPISODE# 117 | TIME_STEPS:      9 | MEMORY_LENGTH:       1188
# EPISODE# 118 | TIME_STEPS:     14 | MEMORY_LENGTH:       1202
# EPISODE# 119 | TIME_STEPS:      9 | MEMORY_LENGTH:       1211
# EPISODE# 120 | TIME_STEPS:      9 | MEMORY_LENGTH:       1220
# EPISODE# 121 | TIME_STEPS:      8 | MEMORY_LENGTH:       1228
# EPISODE# 122 | TIME_STEPS:      9 | MEMORY_LENGTH:       1237
# EPISODE# 123 | TIME_STEPS:     10 | MEMORY_LENGTH:       1247
# EPISODE# 124 | TIME_STEPS:     10 | MEMORY_LENGTH:       1257
# EPISODE# 125 | TIME_STEPS:      9 | MEMORY_LENGTH:       1266
# EPISODE# 126 | TIME_STEPS:     10 | MEMORY_LENGTH:       1276
# EPISODE# 127 | TIME_STEPS:      8 | MEMORY_LENGTH:       1284
# EPISODE# 128 | TIME_STEPS:     10 | MEMORY_LENGTH:       1294
# EPISODE# 129 | TIME_STEPS:     10 | MEMORY_LENGTH:       1304
# EPISODE# 130 | TIME_STEPS:     11 | MEMORY_LENGTH:       1315
# EPISODE# 131 | TIME_STEPS:     11 | MEMORY_LENGTH:       1326
# EPISODE# 132 | TIME_STEPS:     12 | MEMORY_LENGTH:       1338
# EPISODE# 133 | TIME_STEPS:      9 | MEMORY_LENGTH:       1347
# EPISODE# 134 | TIME_STEPS:      9 | MEMORY_LENGTH:       1356
# EPISODE# 135 | TIME_STEPS:     14 | MEMORY_LENGTH:       1370
# EPISODE# 136 | TIME_STEPS:     11 | MEMORY_LENGTH:       1381
# EPISODE# 137 | TIME_STEPS:      9 | MEMORY_LENGTH:       1390
# EPISODE# 138 | TIME_STEPS:     12 | MEMORY_LENGTH:       1402
# EPISODE# 139 | TIME_STEPS:      9 | MEMORY_LENGTH:       1411
# EPISODE# 140 | TIME_STEPS:     10 | MEMORY_LENGTH:       1421
# EPISODE# 141 | TIME_STEPS:     12 | MEMORY_LENGTH:       1433
# EPISODE# 142 | TIME_STEPS:     10 | MEMORY_LENGTH:       1443
# EPISODE# 143 | TIME_STEPS:     11 | MEMORY_LENGTH:       1454
# EPISODE# 144 | TIME_STEPS:      9 | MEMORY_LENGTH:       1463
# EPISODE# 145 | TIME_STEPS:     12 | MEMORY_LENGTH:       1475
# EPISODE# 146 | TIME_STEPS:     11 | MEMORY_LENGTH:       1486
# EPISODE# 147 | TIME_STEPS:     14 | MEMORY_LENGTH:       1500
# EPISODE# 148 | TIME_STEPS:      9 | MEMORY_LENGTH:       1509
# EPISODE# 149 | TIME_STEPS:      9 | MEMORY_LENGTH:       1518
# EPISODE# 150 | TIME_STEPS:      8 | MEMORY_LENGTH:       1526
# EPISODE# 151 | TIME_STEPS:     13 | MEMORY_LENGTH:       1539
# EPISODE# 152 | TIME_STEPS:      9 | MEMORY_LENGTH:       1548
# EPISODE# 153 | TIME_STEPS:      9 | MEMORY_LENGTH:       1557
# EPISODE# 154 | TIME_STEPS:      8 | MEMORY_LENGTH:       1565
# EPISODE# 155 | TIME_STEPS:     11 | MEMORY_LENGTH:       1576
# EPISODE# 156 | TIME_STEPS:     12 | MEMORY_LENGTH:       1588
# EPISODE# 157 | TIME_STEPS:     10 | MEMORY_LENGTH:       1598
# EPISODE# 158 | TIME_STEPS:     13 | MEMORY_LENGTH:       1611
# EPISODE# 159 | TIME_STEPS:     10 | MEMORY_LENGTH:       1621
# EPISODE# 160 | TIME_STEPS:     10 | MEMORY_LENGTH:       1631
# EPISODE# 161 | TIME_STEPS:     10 | MEMORY_LENGTH:       1641
# EPISODE# 162 | TIME_STEPS:      9 | MEMORY_LENGTH:       1650
# EPISODE# 163 | TIME_STEPS:      9 | MEMORY_LENGTH:       1659
# EPISODE# 164 | TIME_STEPS:     10 | MEMORY_LENGTH:       1669
# EPISODE# 165 | TIME_STEPS:      8 | MEMORY_LENGTH:       1677
# EPISODE# 166 | TIME_STEPS:     10 | MEMORY_LENGTH:       1687
# EPISODE# 167 | TIME_STEPS:     12 | MEMORY_LENGTH:       1699
# EPISODE# 168 | TIME_STEPS:     10 | MEMORY_LENGTH:       1709
# EPISODE# 169 | TIME_STEPS:     11 | MEMORY_LENGTH:       1720
# EPISODE# 170 | TIME_STEPS:      9 | MEMORY_LENGTH:       1729
# EPISODE# 171 | TIME_STEPS:     10 | MEMORY_LENGTH:       1739
# EPISODE# 172 | TIME_STEPS:     10 | MEMORY_LENGTH:       1749
# EPISODE# 173 | TIME_STEPS:     10 | MEMORY_LENGTH:       1759
# EPISODE# 174 | TIME_STEPS:     11 | MEMORY_LENGTH:       1770
# EPISODE# 175 | TIME_STEPS:      9 | MEMORY_LENGTH:       1779
# EPISODE# 176 | TIME_STEPS:     10 | MEMORY_LENGTH:       1789
# EPISODE# 177 | TIME_STEPS:      9 | MEMORY_LENGTH:       1798
# EPISODE# 178 | TIME_STEPS:     11 | MEMORY_LENGTH:       1809
# EPISODE# 179 | TIME_STEPS:     12 | MEMORY_LENGTH:       1821
# EPISODE# 180 | TIME_STEPS:     10 | MEMORY_LENGTH:       1831
# EPISODE# 181 | TIME_STEPS:     10 | MEMORY_LENGTH:       1841
# EPISODE# 182 | TIME_STEPS:     10 | MEMORY_LENGTH:       1851
# EPISODE# 183 | TIME_STEPS:      8 | MEMORY_LENGTH:       1859
# EPISODE# 184 | TIME_STEPS:     11 | MEMORY_LENGTH:       1870
# EPISODE# 185 | TIME_STEPS:     10 | MEMORY_LENGTH:       1880
# EPISODE# 186 | TIME_STEPS:     11 | MEMORY_LENGTH:       1891
# EPISODE# 187 | TIME_STEPS:     10 | MEMORY_LENGTH:       1901
# EPISODE# 188 | TIME_STEPS:      8 | MEMORY_LENGTH:       1909
# EPISODE# 189 | TIME_STEPS:      9 | MEMORY_LENGTH:       1918
# EPISODE# 190 | TIME_STEPS:      9 | MEMORY_LENGTH:       1927
# EPISODE# 191 | TIME_STEPS:     12 | MEMORY_LENGTH:       1939
# EPISODE# 192 | TIME_STEPS:     12 | MEMORY_LENGTH:       1951
# EPISODE# 193 | TIME_STEPS:     10 | MEMORY_LENGTH:       1961
# EPISODE# 194 | TIME_STEPS:     13 | MEMORY_LENGTH:       1974
# EPISODE# 195 | TIME_STEPS:      9 | MEMORY_LENGTH:       1983
# EPISODE# 196 | TIME_STEPS:     10 | MEMORY_LENGTH:       1993
# Learning starts from EPISODE:  197
# EPISODE# 197 | TIME_STEPS:      9 | MEMORY_LENGTH:       2000
# EPISODE# 198 | TIME_STEPS:      9 | MEMORY_LENGTH:       2000
# EPISODE# 199 | TIME_STEPS:     33 | MEMORY_LENGTH:       2000
# EPISODE# 200 | TIME_STEPS:     26 | MEMORY_LENGTH:       2000
# EPISODE# 201 | TIME_STEPS:     10 | MEMORY_LENGTH:       2000
# EPISODE# 202 | TIME_STEPS:     26 | MEMORY_LENGTH:       2000
# EPISODE# 203 | TIME_STEPS:     42 | MEMORY_LENGTH:       2000
# EPISODE# 204 | TIME_STEPS:     36 | MEMORY_LENGTH:       2000
# EPISODE# 205 | TIME_STEPS:     54 | MEMORY_LENGTH:       2000
# EPISODE# 206 | TIME_STEPS:    152 | MEMORY_LENGTH:       2000
# EPISODE# 207 | TIME_STEPS:     50 | MEMORY_LENGTH:       2000
# EPISODE# 208 | TIME_STEPS:     58 | MEMORY_LENGTH:       2000
# EPISODE# 209 | TIME_STEPS:     56 | MEMORY_LENGTH:       2000
# EPISODE# 210 | TIME_STEPS:     30 | MEMORY_LENGTH:       2000
# EPISODE# 211 | TIME_STEPS:     45 | MEMORY_LENGTH:       2000
# EPISODE# 212 | TIME_STEPS:     73 | MEMORY_LENGTH:       2000
# EPISODE# 213 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 214 | TIME_STEPS:     96 | MEMORY_LENGTH:       2000
# EPISODE# 215 | TIME_STEPS:     80 | MEMORY_LENGTH:       2000
# EPISODE# 216 | TIME_STEPS:     99 | MEMORY_LENGTH:       2000
# EPISODE# 217 | TIME_STEPS:     68 | MEMORY_LENGTH:       2000
# EPISODE# 218 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 219 | TIME_STEPS:    130 | MEMORY_LENGTH:       2000
# EPISODE# 220 | TIME_STEPS:    145 | MEMORY_LENGTH:       2000
# EPISODE# 221 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 222 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 223 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 224 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 225 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 226 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 227 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 228 | TIME_STEPS:    162 | MEMORY_LENGTH:       2000
# EPISODE# 229 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 230 | TIME_STEPS:    175 | MEMORY_LENGTH:       2000
# EPISODE# 231 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 232 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 233 | TIME_STEPS:     14 | MEMORY_LENGTH:       2000
# EPISODE# 234 | TIME_STEPS:    160 | MEMORY_LENGTH:       2000
# EPISODE# 235 | TIME_STEPS:     38 | MEMORY_LENGTH:       2000
# EPISODE# 236 | TIME_STEPS:    166 | MEMORY_LENGTH:       2000
# EPISODE# 237 | TIME_STEPS:     41 | MEMORY_LENGTH:       2000
# EPISODE# 238 | TIME_STEPS:     31 | MEMORY_LENGTH:       2000
# EPISODE# 239 | TIME_STEPS:    154 | MEMORY_LENGTH:       2000
# EPISODE# 240 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 241 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 242 | TIME_STEPS:    188 | MEMORY_LENGTH:       2000
# EPISODE# 243 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 244 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 245 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 246 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 247 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 248 | TIME_STEPS:    195 | MEMORY_LENGTH:       2000
# EPISODE# 249 | TIME_STEPS:     81 | MEMORY_LENGTH:       2000
# EPISODE# 250 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 251 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 252 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 253 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 254 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 255 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 256 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 257 | TIME_STEPS:    125 | MEMORY_LENGTH:       2000
# EPISODE# 258 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 259 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 260 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 261 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 262 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 263 | TIME_STEPS:    145 | MEMORY_LENGTH:       2000
# EPISODE# 264 | TIME_STEPS:    107 | MEMORY_LENGTH:       2000
# EPISODE# 265 | TIME_STEPS:     87 | MEMORY_LENGTH:       2000
# EPISODE# 266 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 267 | TIME_STEPS:     65 | MEMORY_LENGTH:       2000
# EPISODE# 268 | TIME_STEPS:    197 | MEMORY_LENGTH:       2000
# EPISODE# 269 | TIME_STEPS:    116 | MEMORY_LENGTH:       2000
# EPISODE# 270 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 271 | TIME_STEPS:    188 | MEMORY_LENGTH:       2000
# EPISODE# 272 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 273 | TIME_STEPS:     88 | MEMORY_LENGTH:       2000
# EPISODE# 274 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 275 | TIME_STEPS:    167 | MEMORY_LENGTH:       2000
# EPISODE# 276 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 277 | TIME_STEPS:    118 | MEMORY_LENGTH:       2000
# EPISODE# 278 | TIME_STEPS:    159 | MEMORY_LENGTH:       2000
# EPISODE# 279 | TIME_STEPS:    164 | MEMORY_LENGTH:       2000
# EPISODE# 280 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 281 | TIME_STEPS:     49 | MEMORY_LENGTH:       2000
# EPISODE# 282 | TIME_STEPS:    114 | MEMORY_LENGTH:       2000
# EPISODE# 283 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 284 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 285 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 286 | TIME_STEPS:    144 | MEMORY_LENGTH:       2000
# EPISODE# 287 | TIME_STEPS:     38 | MEMORY_LENGTH:       2000
# EPISODE# 288 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 289 | TIME_STEPS:    152 | MEMORY_LENGTH:       2000
# EPISODE# 290 | TIME_STEPS:     25 | MEMORY_LENGTH:       2000
# EPISODE# 291 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 292 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 293 | TIME_STEPS:    101 | MEMORY_LENGTH:       2000
# EPISODE# 294 | TIME_STEPS:    142 | MEMORY_LENGTH:       2000
# EPISODE# 295 | TIME_STEPS:    128 | MEMORY_LENGTH:       2000
# EPISODE# 296 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 297 | TIME_STEPS:     43 | MEMORY_LENGTH:       2000
# EPISODE# 298 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 299 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 300 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 301 | TIME_STEPS:     24 | MEMORY_LENGTH:       2000
# EPISODE# 302 | TIME_STEPS:    163 | MEMORY_LENGTH:       2000
# EPISODE# 303 | TIME_STEPS:    135 | MEMORY_LENGTH:       2000
# EPISODE# 304 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 305 | TIME_STEPS:    145 | MEMORY_LENGTH:       2000
# EPISODE# 306 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 307 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 308 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 309 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 310 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 311 | TIME_STEPS:    118 | MEMORY_LENGTH:       2000
# EPISODE# 312 | TIME_STEPS:     86 | MEMORY_LENGTH:       2000
# EPISODE# 313 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 314 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 315 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 316 | TIME_STEPS:     23 | MEMORY_LENGTH:       2000
# EPISODE# 317 | TIME_STEPS:     48 | MEMORY_LENGTH:       2000
# EPISODE# 318 | TIME_STEPS:    161 | MEMORY_LENGTH:       2000
# EPISODE# 319 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 320 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 321 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 322 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 323 | TIME_STEPS:     89 | MEMORY_LENGTH:       2000
# EPISODE# 324 | TIME_STEPS:     62 | MEMORY_LENGTH:       2000
# EPISODE# 325 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 326 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 327 | TIME_STEPS:     80 | MEMORY_LENGTH:       2000
# EPISODE# 328 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 329 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 330 | TIME_STEPS:    129 | MEMORY_LENGTH:       2000
# EPISODE# 331 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 332 | TIME_STEPS:    187 | MEMORY_LENGTH:       2000
# EPISODE# 333 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 334 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 335 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 336 | TIME_STEPS:    170 | MEMORY_LENGTH:       2000
# EPISODE# 337 | TIME_STEPS:     97 | MEMORY_LENGTH:       2000
# EPISODE# 338 | TIME_STEPS:    147 | MEMORY_LENGTH:       2000
# EPISODE# 339 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 340 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 341 | TIME_STEPS:    122 | MEMORY_LENGTH:       2000
# EPISODE# 342 | TIME_STEPS:    135 | MEMORY_LENGTH:       2000
# EPISODE# 343 | TIME_STEPS:     14 | MEMORY_LENGTH:       2000
# EPISODE# 344 | TIME_STEPS:    187 | MEMORY_LENGTH:       2000
# EPISODE# 345 | TIME_STEPS:     44 | MEMORY_LENGTH:       2000
# EPISODE# 346 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 347 | TIME_STEPS:    159 | MEMORY_LENGTH:       2000
# EPISODE# 348 | TIME_STEPS:    146 | MEMORY_LENGTH:       2000
# EPISODE# 349 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 350 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 351 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 352 | TIME_STEPS:    178 | MEMORY_LENGTH:       2000
# EPISODE# 353 | TIME_STEPS:    107 | MEMORY_LENGTH:       2000
# EPISODE# 354 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 355 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 356 | TIME_STEPS:     28 | MEMORY_LENGTH:       2000
# EPISODE# 357 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 358 | TIME_STEPS:    169 | MEMORY_LENGTH:       2000
# EPISODE# 359 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 360 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 361 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 362 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 363 | TIME_STEPS:    140 | MEMORY_LENGTH:       2000
# EPISODE# 364 | TIME_STEPS:    165 | MEMORY_LENGTH:       2000
# EPISODE# 365 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 366 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 367 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 368 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 369 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 370 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 371 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 372 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 373 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 374 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 375 | TIME_STEPS:    160 | MEMORY_LENGTH:       2000
# EPISODE# 376 | TIME_STEPS:    190 | MEMORY_LENGTH:       2000
# EPISODE# 377 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 378 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 379 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 380 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 381 | TIME_STEPS:     36 | MEMORY_LENGTH:       2000
# EPISODE# 382 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 383 | TIME_STEPS:     24 | MEMORY_LENGTH:       2000
# EPISODE# 384 | TIME_STEPS:     55 | MEMORY_LENGTH:       2000
# EPISODE# 385 | TIME_STEPS:     38 | MEMORY_LENGTH:       2000
# EPISODE# 386 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 387 | TIME_STEPS:    129 | MEMORY_LENGTH:       2000
# EPISODE# 388 | TIME_STEPS:    153 | MEMORY_LENGTH:       2000
# EPISODE# 389 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 390 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 391 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 392 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 393 | TIME_STEPS:    147 | MEMORY_LENGTH:       2000
# EPISODE# 394 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 395 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 396 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 397 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 398 | TIME_STEPS:     36 | MEMORY_LENGTH:       2000
# EPISODE# 399 | TIME_STEPS:    184 | MEMORY_LENGTH:       2000
# EPISODE# 400 | TIME_STEPS:     48 | MEMORY_LENGTH:       2000
# EPISODE# 401 | TIME_STEPS:     19 | MEMORY_LENGTH:       2000
# EPISODE# 402 | TIME_STEPS:    143 | MEMORY_LENGTH:       2000
# EPISODE# 403 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 404 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 405 | TIME_STEPS:     46 | MEMORY_LENGTH:       2000
# EPISODE# 406 | TIME_STEPS:     31 | MEMORY_LENGTH:       2000
# EPISODE# 407 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 408 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 409 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 410 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 411 | TIME_STEPS:    131 | MEMORY_LENGTH:       2000
# EPISODE# 412 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 413 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 414 | TIME_STEPS:     54 | MEMORY_LENGTH:       2000
# EPISODE# 415 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 416 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 417 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 418 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 419 | TIME_STEPS:    150 | MEMORY_LENGTH:       2000
# EPISODE# 420 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 421 | TIME_STEPS:     87 | MEMORY_LENGTH:       2000
# EPISODE# 422 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 423 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 424 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 425 | TIME_STEPS:     54 | MEMORY_LENGTH:       2000
# EPISODE# 426 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 427 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 428 | TIME_STEPS:    182 | MEMORY_LENGTH:       2000
# EPISODE# 429 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 430 | TIME_STEPS:    129 | MEMORY_LENGTH:       2000
# EPISODE# 431 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 432 | TIME_STEPS:    111 | MEMORY_LENGTH:       2000
# EPISODE# 433 | TIME_STEPS:     91 | MEMORY_LENGTH:       2000
# EPISODE# 434 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 435 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 436 | TIME_STEPS:    116 | MEMORY_LENGTH:       2000
# EPISODE# 437 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 438 | TIME_STEPS:    107 | MEMORY_LENGTH:       2000
# EPISODE# 439 | TIME_STEPS:     16 | MEMORY_LENGTH:       2000
# EPISODE# 440 | TIME_STEPS:     28 | MEMORY_LENGTH:       2000
# EPISODE# 441 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 442 | TIME_STEPS:    160 | MEMORY_LENGTH:       2000
# EPISODE# 443 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 444 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 445 | TIME_STEPS:    102 | MEMORY_LENGTH:       2000
# EPISODE# 446 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 447 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 448 | TIME_STEPS:    163 | MEMORY_LENGTH:       2000
# EPISODE# 449 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 450 | TIME_STEPS:    195 | MEMORY_LENGTH:       2000
# EPISODE# 451 | TIME_STEPS:     76 | MEMORY_LENGTH:       2000
# EPISODE# 452 | TIME_STEPS:     29 | MEMORY_LENGTH:       2000
# EPISODE# 453 | TIME_STEPS:     57 | MEMORY_LENGTH:       2000
# EPISODE# 454 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 455 | TIME_STEPS:     27 | MEMORY_LENGTH:       2000
# EPISODE# 456 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 457 | TIME_STEPS:     85 | MEMORY_LENGTH:       2000
# EPISODE# 458 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 459 | TIME_STEPS:     17 | MEMORY_LENGTH:       2000
# EPISODE# 460 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 461 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 462 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 463 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 464 | TIME_STEPS:    141 | MEMORY_LENGTH:       2000
# EPISODE# 465 | TIME_STEPS:    145 | MEMORY_LENGTH:       2000
# EPISODE# 466 | TIME_STEPS:     69 | MEMORY_LENGTH:       2000
# EPISODE# 467 | TIME_STEPS:    191 | MEMORY_LENGTH:       2000
# EPISODE# 468 | TIME_STEPS:    171 | MEMORY_LENGTH:       2000
# EPISODE# 469 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 470 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 471 | TIME_STEPS:    148 | MEMORY_LENGTH:       2000
# EPISODE# 472 | TIME_STEPS:    163 | MEMORY_LENGTH:       2000
# EPISODE# 473 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 474 | TIME_STEPS:    162 | MEMORY_LENGTH:       2000
# EPISODE# 475 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 476 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 477 | TIME_STEPS:    189 | MEMORY_LENGTH:       2000
# EPISODE# 478 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 479 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 480 | TIME_STEPS:    178 | MEMORY_LENGTH:       2000
# EPISODE# 481 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 482 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 483 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 484 | TIME_STEPS:    159 | MEMORY_LENGTH:       2000
# EPISODE# 485 | TIME_STEPS:    125 | MEMORY_LENGTH:       2000
# EPISODE# 486 | TIME_STEPS:     94 | MEMORY_LENGTH:       2000
# EPISODE# 487 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 488 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 489 | TIME_STEPS:    166 | MEMORY_LENGTH:       2000
# EPISODE# 490 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 491 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 492 | TIME_STEPS:    195 | MEMORY_LENGTH:       2000
# EPISODE# 493 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 494 | TIME_STEPS:     23 | MEMORY_LENGTH:       2000
# EPISODE# 495 | TIME_STEPS:     85 | MEMORY_LENGTH:       2000
# EPISODE# 496 | TIME_STEPS:     74 | MEMORY_LENGTH:       2000
# EPISODE# 497 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 498 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 499 | TIME_STEPS:    188 | MEMORY_LENGTH:       2000
# EPISODE# 500 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 501 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 502 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 503 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 504 | TIME_STEPS:    186 | MEMORY_LENGTH:       2000
# EPISODE# 505 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 506 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 507 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 508 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 509 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 510 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 511 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 512 | TIME_STEPS:    180 | MEMORY_LENGTH:       2000
# EPISODE# 513 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 514 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 515 | TIME_STEPS:    151 | MEMORY_LENGTH:       2000
# EPISODE# 516 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 517 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 518 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 519 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 520 | TIME_STEPS:    180 | MEMORY_LENGTH:       2000
# EPISODE# 521 | TIME_STEPS:    175 | MEMORY_LENGTH:       2000
# EPISODE# 522 | TIME_STEPS:     15 | MEMORY_LENGTH:       2000
# EPISODE# 523 | TIME_STEPS:    148 | MEMORY_LENGTH:       2000
# EPISODE# 524 | TIME_STEPS:     21 | MEMORY_LENGTH:       2000
# EPISODE# 525 | TIME_STEPS:     65 | MEMORY_LENGTH:       2000
# EPISODE# 526 | TIME_STEPS:    106 | MEMORY_LENGTH:       2000
# EPISODE# 527 | TIME_STEPS:    183 | MEMORY_LENGTH:       2000
# EPISODE# 528 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 529 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 530 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 531 | TIME_STEPS:    149 | MEMORY_LENGTH:       2000
# EPISODE# 532 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 533 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 534 | TIME_STEPS:     61 | MEMORY_LENGTH:       2000
# EPISODE# 535 | TIME_STEPS:     26 | MEMORY_LENGTH:       2000
# EPISODE# 536 | TIME_STEPS:     21 | MEMORY_LENGTH:       2000
# EPISODE# 537 | TIME_STEPS:     85 | MEMORY_LENGTH:       2000
# EPISODE# 538 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 539 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 540 | TIME_STEPS:    156 | MEMORY_LENGTH:       2000
# EPISODE# 541 | TIME_STEPS:    183 | MEMORY_LENGTH:       2000
# EPISODE# 542 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 543 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 544 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 545 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 546 | TIME_STEPS:    187 | MEMORY_LENGTH:       2000
# EPISODE# 547 | TIME_STEPS:    163 | MEMORY_LENGTH:       2000
# EPISODE# 548 | TIME_STEPS:    192 | MEMORY_LENGTH:       2000
# EPISODE# 549 | TIME_STEPS:    153 | MEMORY_LENGTH:       2000
# EPISODE# 550 | TIME_STEPS:    134 | MEMORY_LENGTH:       2000
# EPISODE# 551 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 552 | TIME_STEPS:     43 | MEMORY_LENGTH:       2000
# EPISODE# 553 | TIME_STEPS:     71 | MEMORY_LENGTH:       2000
# EPISODE# 554 | TIME_STEPS:     78 | MEMORY_LENGTH:       2000
# EPISODE# 555 | TIME_STEPS:     81 | MEMORY_LENGTH:       2000
# EPISODE# 556 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 557 | TIME_STEPS:     67 | MEMORY_LENGTH:       2000
# EPISODE# 558 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 559 | TIME_STEPS:    120 | MEMORY_LENGTH:       2000
# EPISODE# 560 | TIME_STEPS:    118 | MEMORY_LENGTH:       2000
# EPISODE# 561 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 562 | TIME_STEPS:    199 | MEMORY_LENGTH:       2000
# EPISODE# 563 | TIME_STEPS:    192 | MEMORY_LENGTH:       2000
# EPISODE# 564 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 565 | TIME_STEPS:    165 | MEMORY_LENGTH:       2000
# EPISODE# 566 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 567 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 568 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 569 | TIME_STEPS:     67 | MEMORY_LENGTH:       2000
# EPISODE# 570 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 571 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 572 | TIME_STEPS:    126 | MEMORY_LENGTH:       2000
# EPISODE# 573 | TIME_STEPS:     48 | MEMORY_LENGTH:       2000
# EPISODE# 574 | TIME_STEPS:     96 | MEMORY_LENGTH:       2000
# EPISODE# 575 | TIME_STEPS:    140 | MEMORY_LENGTH:       2000
# EPISODE# 576 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 577 | TIME_STEPS:     41 | MEMORY_LENGTH:       2000
# EPISODE# 578 | TIME_STEPS:     33 | MEMORY_LENGTH:       2000
# EPISODE# 579 | TIME_STEPS:     15 | MEMORY_LENGTH:       2000
# EPISODE# 580 | TIME_STEPS:     11 | MEMORY_LENGTH:       2000
# EPISODE# 581 | TIME_STEPS:    102 | MEMORY_LENGTH:       2000
# EPISODE# 582 | TIME_STEPS:    153 | MEMORY_LENGTH:       2000
# EPISODE# 583 | TIME_STEPS:    153 | MEMORY_LENGTH:       2000
# EPISODE# 584 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 585 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 586 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 587 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 588 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 589 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 590 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 591 | TIME_STEPS:    180 | MEMORY_LENGTH:       2000
# EPISODE# 592 | TIME_STEPS:    183 | MEMORY_LENGTH:       2000
# EPISODE# 593 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 594 | TIME_STEPS:    131 | MEMORY_LENGTH:       2000
# EPISODE# 595 | TIME_STEPS:    134 | MEMORY_LENGTH:       2000
# EPISODE# 596 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 597 | TIME_STEPS:    156 | MEMORY_LENGTH:       2000
# EPISODE# 598 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 599 | TIME_STEPS:     97 | MEMORY_LENGTH:       2000
# EPISODE# 600 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 601 | TIME_STEPS:    183 | MEMORY_LENGTH:       2000
# EPISODE# 602 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 603 | TIME_STEPS:    199 | MEMORY_LENGTH:       2000
# EPISODE# 604 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 605 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 606 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 607 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 608 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 609 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 610 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 611 | TIME_STEPS:    186 | MEMORY_LENGTH:       2000
# EPISODE# 612 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 613 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 614 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 615 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 616 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 617 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 618 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 619 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 620 | TIME_STEPS:     18 | MEMORY_LENGTH:       2000
# EPISODE# 621 | TIME_STEPS:      9 | MEMORY_LENGTH:       2000
# EPISODE# 622 | TIME_STEPS:    163 | MEMORY_LENGTH:       2000
# EPISODE# 623 | TIME_STEPS:     86 | MEMORY_LENGTH:       2000
# EPISODE# 624 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 625 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 626 | TIME_STEPS:    166 | MEMORY_LENGTH:       2000
# EPISODE# 627 | TIME_STEPS:    160 | MEMORY_LENGTH:       2000
# EPISODE# 628 | TIME_STEPS:    143 | MEMORY_LENGTH:       2000
# EPISODE# 629 | TIME_STEPS:    144 | MEMORY_LENGTH:       2000
# EPISODE# 630 | TIME_STEPS:    147 | MEMORY_LENGTH:       2000
# EPISODE# 631 | TIME_STEPS:    141 | MEMORY_LENGTH:       2000
# EPISODE# 632 | TIME_STEPS:    125 | MEMORY_LENGTH:       2000
# EPISODE# 633 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 634 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 635 | TIME_STEPS:     89 | MEMORY_LENGTH:       2000
# EPISODE# 636 | TIME_STEPS:    101 | MEMORY_LENGTH:       2000
# EPISODE# 637 | TIME_STEPS:    102 | MEMORY_LENGTH:       2000
# EPISODE# 638 | TIME_STEPS:     20 | MEMORY_LENGTH:       2000
# EPISODE# 639 | TIME_STEPS:     29 | MEMORY_LENGTH:       2000
# EPISODE# 640 | TIME_STEPS:     21 | MEMORY_LENGTH:       2000
# EPISODE# 641 | TIME_STEPS:     19 | MEMORY_LENGTH:       2000
# EPISODE# 642 | TIME_STEPS:     16 | MEMORY_LENGTH:       2000
# EPISODE# 643 | TIME_STEPS:     29 | MEMORY_LENGTH:       2000
# EPISODE# 644 | TIME_STEPS:     49 | MEMORY_LENGTH:       2000
# EPISODE# 645 | TIME_STEPS:     19 | MEMORY_LENGTH:       2000
# EPISODE# 646 | TIME_STEPS:    104 | MEMORY_LENGTH:       2000
# EPISODE# 647 | TIME_STEPS:     21 | MEMORY_LENGTH:       2000
# EPISODE# 648 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 649 | TIME_STEPS:    135 | MEMORY_LENGTH:       2000
# EPISODE# 650 | TIME_STEPS:     57 | MEMORY_LENGTH:       2000
# EPISODE# 651 | TIME_STEPS:     98 | MEMORY_LENGTH:       2000
# EPISODE# 652 | TIME_STEPS:    179 | MEMORY_LENGTH:       2000
# EPISODE# 653 | TIME_STEPS:    182 | MEMORY_LENGTH:       2000
# EPISODE# 654 | TIME_STEPS:    191 | MEMORY_LENGTH:       2000
# EPISODE# 655 | TIME_STEPS:     95 | MEMORY_LENGTH:       2000
# EPISODE# 656 | TIME_STEPS:     43 | MEMORY_LENGTH:       2000
# EPISODE# 657 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 658 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 659 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 660 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 661 | TIME_STEPS:     74 | MEMORY_LENGTH:       2000
# EPISODE# 662 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 663 | TIME_STEPS:    175 | MEMORY_LENGTH:       2000
# EPISODE# 664 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 665 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 666 | TIME_STEPS:    185 | MEMORY_LENGTH:       2000
# EPISODE# 667 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 668 | TIME_STEPS:     61 | MEMORY_LENGTH:       2000
# EPISODE# 669 | TIME_STEPS:     64 | MEMORY_LENGTH:       2000
# EPISODE# 670 | TIME_STEPS:     67 | MEMORY_LENGTH:       2000
# EPISODE# 671 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 672 | TIME_STEPS:     20 | MEMORY_LENGTH:       2000
# EPISODE# 673 | TIME_STEPS:    150 | MEMORY_LENGTH:       2000
# EPISODE# 674 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 675 | TIME_STEPS:    198 | MEMORY_LENGTH:       2000
# EPISODE# 676 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 677 | TIME_STEPS:    170 | MEMORY_LENGTH:       2000
# EPISODE# 678 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 679 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 680 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 681 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 682 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 683 | TIME_STEPS:     68 | MEMORY_LENGTH:       2000
# EPISODE# 684 | TIME_STEPS:    118 | MEMORY_LENGTH:       2000
# EPISODE# 685 | TIME_STEPS:    170 | MEMORY_LENGTH:       2000
# EPISODE# 686 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 687 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 688 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 689 | TIME_STEPS:    179 | MEMORY_LENGTH:       2000
# EPISODE# 690 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 691 | TIME_STEPS:    155 | MEMORY_LENGTH:       2000
# EPISODE# 692 | TIME_STEPS:    157 | MEMORY_LENGTH:       2000
# EPISODE# 693 | TIME_STEPS:    149 | MEMORY_LENGTH:       2000
# EPISODE# 694 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 695 | TIME_STEPS:    150 | MEMORY_LENGTH:       2000
# EPISODE# 696 | TIME_STEPS:    195 | MEMORY_LENGTH:       2000
# EPISODE# 697 | TIME_STEPS:    191 | MEMORY_LENGTH:       2000
# EPISODE# 698 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 699 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 700 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 701 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 702 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 703 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 704 | TIME_STEPS:    192 | MEMORY_LENGTH:       2000
# EPISODE# 705 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 706 | TIME_STEPS:    189 | MEMORY_LENGTH:       2000
# EPISODE# 707 | TIME_STEPS:    147 | MEMORY_LENGTH:       2000
# EPISODE# 708 | TIME_STEPS:    166 | MEMORY_LENGTH:       2000
# EPISODE# 709 | TIME_STEPS:    146 | MEMORY_LENGTH:       2000
# EPISODE# 710 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 711 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 712 | TIME_STEPS:    169 | MEMORY_LENGTH:       2000
# EPISODE# 713 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 714 | TIME_STEPS:    140 | MEMORY_LENGTH:       2000
# EPISODE# 715 | TIME_STEPS:    185 | MEMORY_LENGTH:       2000
# EPISODE# 716 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 717 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 718 | TIME_STEPS:    103 | MEMORY_LENGTH:       2000
# EPISODE# 719 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 720 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 721 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 722 | TIME_STEPS:    185 | MEMORY_LENGTH:       2000
# EPISODE# 723 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 724 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 725 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 726 | TIME_STEPS:    141 | MEMORY_LENGTH:       2000
# EPISODE# 727 | TIME_STEPS:    106 | MEMORY_LENGTH:       2000
# EPISODE# 728 | TIME_STEPS:     48 | MEMORY_LENGTH:       2000
# EPISODE# 729 | TIME_STEPS:    124 | MEMORY_LENGTH:       2000
# EPISODE# 730 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 731 | TIME_STEPS:    125 | MEMORY_LENGTH:       2000
# EPISODE# 732 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 733 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 734 | TIME_STEPS:    134 | MEMORY_LENGTH:       2000
# EPISODE# 735 | TIME_STEPS:    117 | MEMORY_LENGTH:       2000
# EPISODE# 736 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 737 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 738 | TIME_STEPS:    186 | MEMORY_LENGTH:       2000
# EPISODE# 739 | TIME_STEPS:    191 | MEMORY_LENGTH:       2000
# EPISODE# 740 | TIME_STEPS:    155 | MEMORY_LENGTH:       2000
# EPISODE# 741 | TIME_STEPS:    195 | MEMORY_LENGTH:       2000
# EPISODE# 742 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 743 | TIME_STEPS:     11 | MEMORY_LENGTH:       2000
# EPISODE# 744 | TIME_STEPS:    161 | MEMORY_LENGTH:       2000
# EPISODE# 745 | TIME_STEPS:    114 | MEMORY_LENGTH:       2000
# EPISODE# 746 | TIME_STEPS:    120 | MEMORY_LENGTH:       2000
# EPISODE# 747 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 748 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 749 | TIME_STEPS:    122 | MEMORY_LENGTH:       2000
# EPISODE# 750 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 751 | TIME_STEPS:    159 | MEMORY_LENGTH:       2000
# EPISODE# 752 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 753 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 754 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 755 | TIME_STEPS:    150 | MEMORY_LENGTH:       2000
# EPISODE# 756 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 757 | TIME_STEPS:    145 | MEMORY_LENGTH:       2000
# EPISODE# 758 | TIME_STEPS:     67 | MEMORY_LENGTH:       2000
# EPISODE# 759 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 760 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 761 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 762 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 763 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 764 | TIME_STEPS:     12 | MEMORY_LENGTH:       2000
# EPISODE# 765 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 766 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 767 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 768 | TIME_STEPS:     14 | MEMORY_LENGTH:       2000
# EPISODE# 769 | TIME_STEPS:    170 | MEMORY_LENGTH:       2000
# EPISODE# 770 | TIME_STEPS:    164 | MEMORY_LENGTH:       2000
# EPISODE# 771 | TIME_STEPS:    156 | MEMORY_LENGTH:       2000
# EPISODE# 772 | TIME_STEPS:    166 | MEMORY_LENGTH:       2000
# EPISODE# 773 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 774 | TIME_STEPS:    153 | MEMORY_LENGTH:       2000
# EPISODE# 775 | TIME_STEPS:    164 | MEMORY_LENGTH:       2000
# EPISODE# 776 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 777 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 778 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 779 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 780 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 781 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 782 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 783 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 784 | TIME_STEPS:     84 | MEMORY_LENGTH:       2000
# EPISODE# 785 | TIME_STEPS:    142 | MEMORY_LENGTH:       2000
# EPISODE# 786 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 787 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 788 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 789 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 790 | TIME_STEPS:    134 | MEMORY_LENGTH:       2000
# EPISODE# 791 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 792 | TIME_STEPS:     64 | MEMORY_LENGTH:       2000
# EPISODE# 793 | TIME_STEPS:     63 | MEMORY_LENGTH:       2000
# EPISODE# 794 | TIME_STEPS:     39 | MEMORY_LENGTH:       2000
# EPISODE# 795 | TIME_STEPS:     25 | MEMORY_LENGTH:       2000
# EPISODE# 796 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 797 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 798 | TIME_STEPS:    151 | MEMORY_LENGTH:       2000
# EPISODE# 799 | TIME_STEPS:    180 | MEMORY_LENGTH:       2000
# EPISODE# 800 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 801 | TIME_STEPS:    188 | MEMORY_LENGTH:       2000
# EPISODE# 802 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 803 | TIME_STEPS:    179 | MEMORY_LENGTH:       2000
# EPISODE# 804 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 805 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 806 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 807 | TIME_STEPS:    165 | MEMORY_LENGTH:       2000
# EPISODE# 808 | TIME_STEPS:    164 | MEMORY_LENGTH:       2000
# EPISODE# 809 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 810 | TIME_STEPS:    172 | MEMORY_LENGTH:       2000
# EPISODE# 811 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 812 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 813 | TIME_STEPS:     30 | MEMORY_LENGTH:       2000
# EPISODE# 814 | TIME_STEPS:     74 | MEMORY_LENGTH:       2000
# EPISODE# 815 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 816 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 817 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 818 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 819 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 820 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 821 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 822 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 823 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 824 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 825 | TIME_STEPS:    149 | MEMORY_LENGTH:       2000
# EPISODE# 826 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 827 | TIME_STEPS:     62 | MEMORY_LENGTH:       2000
# EPISODE# 828 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 829 | TIME_STEPS:    142 | MEMORY_LENGTH:       2000
# EPISODE# 830 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 831 | TIME_STEPS:    148 | MEMORY_LENGTH:       2000
# EPISODE# 832 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 833 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 834 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 835 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 836 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 837 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 838 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 839 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 840 | TIME_STEPS:    193 | MEMORY_LENGTH:       2000
# EPISODE# 841 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 842 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 843 | TIME_STEPS:    114 | MEMORY_LENGTH:       2000
# EPISODE# 844 | TIME_STEPS:    161 | MEMORY_LENGTH:       2000
# EPISODE# 845 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 846 | TIME_STEPS:    177 | MEMORY_LENGTH:       2000
# EPISODE# 847 | TIME_STEPS:    149 | MEMORY_LENGTH:       2000
# EPISODE# 848 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 849 | TIME_STEPS:    150 | MEMORY_LENGTH:       2000
# EPISODE# 850 | TIME_STEPS:    160 | MEMORY_LENGTH:       2000
# EPISODE# 851 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 852 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 853 | TIME_STEPS:    131 | MEMORY_LENGTH:       2000
# EPISODE# 854 | TIME_STEPS:    159 | MEMORY_LENGTH:       2000
# EPISODE# 855 | TIME_STEPS:    164 | MEMORY_LENGTH:       2000
# EPISODE# 856 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 857 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 858 | TIME_STEPS:    162 | MEMORY_LENGTH:       2000
# EPISODE# 859 | TIME_STEPS:     91 | MEMORY_LENGTH:       2000
# EPISODE# 860 | TIME_STEPS:     25 | MEMORY_LENGTH:       2000
# EPISODE# 861 | TIME_STEPS:     10 | MEMORY_LENGTH:       2000
# EPISODE# 862 | TIME_STEPS:     18 | MEMORY_LENGTH:       2000
# EPISODE# 863 | TIME_STEPS:     12 | MEMORY_LENGTH:       2000
# EPISODE# 864 | TIME_STEPS:     12 | MEMORY_LENGTH:       2000
# EPISODE# 865 | TIME_STEPS:     27 | MEMORY_LENGTH:       2000
# EPISODE# 866 | TIME_STEPS:     97 | MEMORY_LENGTH:       2000
# EPISODE# 867 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 868 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 869 | TIME_STEPS:    176 | MEMORY_LENGTH:       2000
# EPISODE# 870 | TIME_STEPS:    173 | MEMORY_LENGTH:       2000
# EPISODE# 871 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 872 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 873 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 874 | TIME_STEPS:    167 | MEMORY_LENGTH:       2000
# EPISODE# 875 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 876 | TIME_STEPS:    168 | MEMORY_LENGTH:       2000
# EPISODE# 877 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 878 | TIME_STEPS:    193 | MEMORY_LENGTH:       2000
# EPISODE# 879 | TIME_STEPS:    179 | MEMORY_LENGTH:       2000
# EPISODE# 880 | TIME_STEPS:    151 | MEMORY_LENGTH:       2000
# EPISODE# 881 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 882 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 883 | TIME_STEPS:     89 | MEMORY_LENGTH:       2000
# EPISODE# 884 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 885 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 886 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 887 | TIME_STEPS:     36 | MEMORY_LENGTH:       2000
# EPISODE# 888 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 889 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 890 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 891 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 892 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 893 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 894 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 895 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 896 | TIME_STEPS:    138 | MEMORY_LENGTH:       2000
# EPISODE# 897 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 898 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 899 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 900 | TIME_STEPS:    181 | MEMORY_LENGTH:       2000
# EPISODE# 901 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 902 | TIME_STEPS:    158 | MEMORY_LENGTH:       2000
# EPISODE# 903 | TIME_STEPS:     27 | MEMORY_LENGTH:       2000
# EPISODE# 904 | TIME_STEPS:     79 | MEMORY_LENGTH:       2000
# EPISODE# 905 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 906 | TIME_STEPS:    174 | MEMORY_LENGTH:       2000
# EPISODE# 907 | TIME_STEPS:    134 | MEMORY_LENGTH:       2000
# EPISODE# 908 | TIME_STEPS:    109 | MEMORY_LENGTH:       2000
# EPISODE# 909 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 910 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 911 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 912 | TIME_STEPS:    146 | MEMORY_LENGTH:       2000
# EPISODE# 913 | TIME_STEPS:    151 | MEMORY_LENGTH:       2000
# EPISODE# 914 | TIME_STEPS:    149 | MEMORY_LENGTH:       2000
# EPISODE# 915 | TIME_STEPS:    143 | MEMORY_LENGTH:       2000
# EPISODE# 916 | TIME_STEPS:    136 | MEMORY_LENGTH:       2000
# EPISODE# 917 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 918 | TIME_STEPS:    200 | MEMORY_LENGTH:       2000
# EPISODE# 919 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 920 | TIME_STEPS:     46 | MEMORY_LENGTH:       2000
# EPISODE# 921 | TIME_STEPS:     92 | MEMORY_LENGTH:       2000
# EPISODE# 922 | TIME_STEPS:    101 | MEMORY_LENGTH:       2000
# EPISODE# 923 | TIME_STEPS:    107 | MEMORY_LENGTH:       2000
# EPISODE# 924 | TIME_STEPS:     96 | MEMORY_LENGTH:       2000
# EPISODE# 925 | TIME_STEPS:    111 | MEMORY_LENGTH:       2000
# EPISODE# 926 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 927 | TIME_STEPS:    124 | MEMORY_LENGTH:       2000
# EPISODE# 928 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 929 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 930 | TIME_STEPS:    111 | MEMORY_LENGTH:       2000
# EPISODE# 931 | TIME_STEPS:    100 | MEMORY_LENGTH:       2000
# EPISODE# 932 | TIME_STEPS:     99 | MEMORY_LENGTH:       2000
# EPISODE# 933 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 934 | TIME_STEPS:    111 | MEMORY_LENGTH:       2000
# EPISODE# 935 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 936 | TIME_STEPS:    118 | MEMORY_LENGTH:       2000
# EPISODE# 937 | TIME_STEPS:    117 | MEMORY_LENGTH:       2000
# EPISODE# 938 | TIME_STEPS:     18 | MEMORY_LENGTH:       2000
# EPISODE# 939 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 940 | TIME_STEPS:    103 | MEMORY_LENGTH:       2000
# EPISODE# 941 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 942 | TIME_STEPS:    103 | MEMORY_LENGTH:       2000
# EPISODE# 943 | TIME_STEPS:    103 | MEMORY_LENGTH:       2000
# EPISODE# 944 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 945 | TIME_STEPS:     42 | MEMORY_LENGTH:       2000
# EPISODE# 946 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 947 | TIME_STEPS:    103 | MEMORY_LENGTH:       2000
# EPISODE# 948 | TIME_STEPS:     79 | MEMORY_LENGTH:       2000
# EPISODE# 949 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 950 | TIME_STEPS:     99 | MEMORY_LENGTH:       2000
# EPISODE# 951 | TIME_STEPS:     68 | MEMORY_LENGTH:       2000
# EPISODE# 952 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 953 | TIME_STEPS:    117 | MEMORY_LENGTH:       2000
# EPISODE# 954 | TIME_STEPS:    101 | MEMORY_LENGTH:       2000
# EPISODE# 955 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 956 | TIME_STEPS:    135 | MEMORY_LENGTH:       2000
# EPISODE# 957 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 958 | TIME_STEPS:    128 | MEMORY_LENGTH:       2000
# EPISODE# 959 | TIME_STEPS:    122 | MEMORY_LENGTH:       2000
# EPISODE# 960 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 961 | TIME_STEPS:    131 | MEMORY_LENGTH:       2000
# EPISODE# 962 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 963 | TIME_STEPS:    104 | MEMORY_LENGTH:       2000
# EPISODE# 964 | TIME_STEPS:    105 | MEMORY_LENGTH:       2000
# EPISODE# 965 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 966 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 967 | TIME_STEPS:    129 | MEMORY_LENGTH:       2000
# EPISODE# 968 | TIME_STEPS:    122 | MEMORY_LENGTH:       2000
# EPISODE# 969 | TIME_STEPS:    132 | MEMORY_LENGTH:       2000
# EPISODE# 970 | TIME_STEPS:    135 | MEMORY_LENGTH:       2000
# EPISODE# 971 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 972 | TIME_STEPS:    133 | MEMORY_LENGTH:       2000
# EPISODE# 973 | TIME_STEPS:    119 | MEMORY_LENGTH:       2000
# EPISODE# 974 | TIME_STEPS:     86 | MEMORY_LENGTH:       2000
# EPISODE# 975 | TIME_STEPS:     59 | MEMORY_LENGTH:       2000
# EPISODE# 976 | TIME_STEPS:    112 | MEMORY_LENGTH:       2000
# EPISODE# 977 | TIME_STEPS:     99 | MEMORY_LENGTH:       2000
# EPISODE# 978 | TIME_STEPS:    110 | MEMORY_LENGTH:       2000
# EPISODE# 979 | TIME_STEPS:    113 | MEMORY_LENGTH:       2000
# EPISODE# 980 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 981 | TIME_STEPS:    116 | MEMORY_LENGTH:       2000
# EPISODE# 982 | TIME_STEPS:     88 | MEMORY_LENGTH:       2000
# EPISODE# 983 | TIME_STEPS:     91 | MEMORY_LENGTH:       2000
# EPISODE# 984 | TIME_STEPS:    109 | MEMORY_LENGTH:       2000
# EPISODE# 985 | TIME_STEPS:     73 | MEMORY_LENGTH:       2000
# EPISODE# 986 | TIME_STEPS:    124 | MEMORY_LENGTH:       2000
# EPISODE# 987 | TIME_STEPS:    137 | MEMORY_LENGTH:       2000
# EPISODE# 988 | TIME_STEPS:    139 | MEMORY_LENGTH:       2000
# EPISODE# 989 | TIME_STEPS:    108 | MEMORY_LENGTH:       2000
# EPISODE# 990 | TIME_STEPS:    126 | MEMORY_LENGTH:       2000
# EPISODE# 991 | TIME_STEPS:    127 | MEMORY_LENGTH:       2000
# EPISODE# 992 | TIME_STEPS:    131 | MEMORY_LENGTH:       2000
# EPISODE# 993 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000
# EPISODE# 994 | TIME_STEPS:    117 | MEMORY_LENGTH:       2000
# EPISODE# 995 | TIME_STEPS:    115 | MEMORY_LENGTH:       2000
# EPISODE# 996 | TIME_STEPS:    116 | MEMORY_LENGTH:       2000
# EPISODE# 997 | TIME_STEPS:    128 | MEMORY_LENGTH:       2000
# EPISODE# 998 | TIME_STEPS:    121 | MEMORY_LENGTH:       2000
# EPISODE# 999 | TIME_STEPS:    123 | MEMORY_LENGTH:       2000

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec
ax2.plot(data, color = 'g')
# ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_xlabel('Iterations',color = 'k')
ax2.set_ylabel('Time Steps',color = 'g')
# ax2.set_ylim([1,2.5e2])
# ax2.set_yscale('log')

fig.tight_layout()
ax2.grid()
plt.show()

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()
